# %% [markdown]
# <h1>GrEx3: Hotel Customers Have Their Say About Brands</h1><br>
# Eric Randall<br>
# PREDICT 420: Summer 2017

# %%
import pandas as pd
import numpy as np
import glob
import os
import json
import math
import re
import stop_words
from stemming.porter2 import stem
import nltk

# %% [markdown]
# <b>Part 1: Providing structure to our json files</b><br>The first part of our task is to create a list of json files in the data directory and loop through all of them to add all the data we need to a temporary dictionary that will be merged into a series at the end of the loop. Try/Except is applied to catch reviews that chose not to fill out all of the fields in the survey.

# %%
json_files = glob.glob("data\\*.json")
reviewsmaster = []
for files in json_files:
    with open(files) as input_file:
        jsondat=json.load(input_file)
    for review in jsondat['Reviews']:
        temp_dict = {}
        temp_dict['Author'] = review['Author'].encode("utf-8")
        temp_dict['Date'] = review['Date'].encode("utf-8")
        temp_dict['ReviewID'] = review['ReviewID'].encode("utf-8")
        temp_dict['HotelNameURL'] = jsondat['HotelInfo']['HotelURL'].encode("utf-8")
        temp_dict['HotelID'] = jsondat['HotelInfo']['HotelID'].encode("utf-8")
        try:
            temp_dict['HotelName'] = str(jsondat['HotelInfo']['Name'].encode("utf-8"))
        except:
            temp_dict['HotelName'] = str("")
        try:
            temp_dict['RCleanliness'] = int(review['Ratings']['Cleanliness'].encode("utf-8"))
        except:
            temp_dict['RCleanliness'] = np.nan
        try:
            temp_dict['RLocation'] = int(review['Ratings']['Location'].encode("utf-8"))
        except:
            temp_dict['RLocation'] = np.nan
        try:
            temp_dict['ROverall'] = int(review['Ratings']['Overall'].encode("utf-8"))
        except:
            temp_dict['ROverall'] = np.nan
        try:
            temp_dict['RRooms'] = int(review['Ratings']['Rooms'].encode("utf-8"))
        except:
            temp_dict['RRooms'] = np.nan
        try:
            temp_dict['RService'] = int(review['Ratings']['Service'].encode("utf-8"))
        except:
            temp_dict['RService'] = np.nan
        try:
            temp_dict['RSleepQual'] = int(review['Ratings']['Sleep Quality'].encode("utf-8"))
        except:
            temp_dict['RSleepQual'] = np.nan
        try:
            temp_dict['RValue'] = int(review['Ratings']['Value'].encode("utf-8"))
        except:
            temp_dict['RValue'] = np.nan
        try:
            temp_dict['RCheckIn'] = int(review['Ratings']['Check in / front desk'].encode("utf-8"))
        except:
            temp_dict['RCheckIn'] = np.nan
        try:
            temp_dict['RBusinessService'] = int(review['Ratings']['Business service (e.g., internet access)']
                                                .encode("utf-8"))
        except:
            try:
                temp_dict['RBusinessService'] = int(review['Ratings']['Business service'].encode("utf-8"))
            except:
                temp_dict['RBusinessService'] = np.nan
        reviewsmaster.append(temp_dict)

# %%
# Convert from series into DataFrame.  
reviews_df = pd.DataFrame(reviewsmaster)

# %%
# Convert these to strings. 
reviews_df['Author'] = reviews_df['Author'].astype(str)
reviews_df['Date'] = reviews_df['Date'].astype(str)
reviews_df['HotelName'] = reviews_df['HotelName'].astype(str)
reviews_df['ReviewID'] = reviews_df['ReviewID'].astype(str)

# -1 is converted to NaN. All the ratings are float64.  
reviews_df = reviews_df.replace(to_replace={
        'RCheckIn': {-1 : np.nan}, 
        'RBusinessService': {-1 : np.nan},
        'RCleanliness': {-1 : np.nan},
        'RLocation': {-1 : np.nan},
        'RRooms': {-1 : np.nan},
        'RService': {-1 : np.nan},
        'RValue': {-1 : np.nan},
        })

#reviews_df.dtypes

# %%
# Extract the name of the hotel from the URL because there was more data there than the HotelName 
# field that was often blank.
tempHotelNameFix = []

for row in reviews_df['HotelNameURL']:
    trimmed = row.split('ShowUserReviews-', 1)[1]
    try:
        trimmed = trimmed.split('Reviews')[1]
    except:
        trimmed = trimmed
    trimmed = trimmed.split('.html', 1)[0]
    trim2 = re.split('\d', trimmed)[len(re.split('\d', trimmed)) - 1][1:]
    trim2 = trim2.replace("_"," ")
    tempHotelNameFix.append(trim2)
reviews_df['HotelNameFix'] = tempHotelNameFix

# %%
# If HotelName was blank, use name extracted from URL.
reviews_df['HotelName'] = np.where(reviews_df['HotelName'] == '', reviews_df['HotelNameFix'], 
                                   reviews_df['HotelName'])

# %%
# Drop URL and fixed name columns because we've used them.  
reviews_df = reviews_df.drop('HotelNameFix', 1)
reviews_df = reviews_df.drop('HotelNameURL', 1)

# %%
# 1b: Number of reviews per hotel:  
pd.crosstab(index=reviews_df["HotelName"], columns="count")
# Out:
# col_0                                               count
# HotelName
# A Victory Inn & Suites Phoenix North                   32
# BEST WESTERN Airport Inn                               45
# BEST WESTERN Loyal Inn                                113
# BEST WESTERN Market Center                             54
# BEST WESTERN PLUS Executive Inn                       137
# BEST WESTERN PLUS InnSuites Phoenix Hotel & Suites     60
# BEST WESTERN PLUS Pioneer Square Hotel                233
# Balisandy Cottages-Kuta Bali                            1
# Christopher's Inn                                      93
# Comfort Inn & Suites Seattle                           36
# Courtyard by Marriott Phoenix North                    19
# Days Inn Camelback Phoenix and Conference Center       39
# Days Inn I-17 & Thomas                                 24
# Deca Hotel-Seattle Washington                           1
# Grace Inn Phoenix                                      44
# Hotel Banys Orientals                                 188
# Hotel Seattle                                          48
# Kendall Hotel and Suites                               52
# Lexington Hotel Central Phoenix                        57
# Meninas Hotel                                         167
# Park Shore Waikiki-Honolulu Oahu Hawaii               174
# Plaza Madrid-Mexico City Central Mexico and Gul...      1
# Renaissance Phoenix Downtown                           36
# Riu Bambu-Punta Cana Dominican Republic               710
# San Diego Marriott Mission Valley                      96
# Super 8 Phoenix                                        25

# %%
pd.crosstab(index=reviews_df["RLocation"], columns="count", dropna=False)
# Out:
# col_0      count
# RLocation
# 1.0           52
# 2.0           74
# 3.0          206
# 4.0          430
# 5.0          953

# %%
# 1c: Across hotels, calculate and report statistics describing the distribution of the overall rating received 
# by the hotels.  
reviews_df.describe()
# Out:
#        RBusinessService    RCheckIn  RCleanliness    RLocation    ROverall  \
# count        483.000000  735.000000   2098.000000  1715.000000  887.000000
# mean           3.534161    3.975510      3.978551     4.258309    3.839910
# std            1.259146    1.173945      1.222511     1.027217    1.218401
# min            1.000000    1.000000      1.000000     1.000000    1.000000
# 25%            3.000000    3.000000      3.000000     4.000000    3.000000
# 50%            4.000000    4.000000      4.000000     5.000000    4.000000
# 75%            5.000000    5.000000      5.000000     5.000000    5.000000
# max            5.000000    5.000000      5.000000     5.000000    5.000000
#
#             RRooms     RService  RSleepQual       RValue
# count  1981.000000  2097.000000  805.000000  2100.000000
# mean      3.582029     3.927039    3.816149     3.854762
# std       1.251246     1.258907    1.279765     1.271729
# min       1.000000     1.000000    1.000000     1.000000
# 25%       3.000000     3.000000    3.000000     3.000000
# 50%       4.000000     4.000000    4.000000     4.000000
# 75%       5.000000     5.000000    5.000000     5.000000
# max       5.000000     5.000000    5.000000     5.000000

# %%
# 1d: Pickle and test pickling.  
reviews_df.to_pickle("reviews.pkl")
#reviews_pickle = pd.read_pickle("reviews.pkl")

# %% [markdown]
# <b>Part 2: Text Data for Perceptual Mapping</b><br>Now we must filter out stop-words, punctuation, and create a dictionary for each hotel's descriptors.<br> The end goal is a JSON file and a count of the unique words describing each hotel.

# %%
# Acquire stop-words, Convert to unicode and strip out punctuation.  
remove_words = stop_words.get_stop_words('english')
remove_words_temp = []
for word in remove_words:
    remove_words_temp.append(re.sub(r'[^\w\s]|\d','',word.encode("utf-8")))
remove_words = remove_words_temp

# %%
hotWords = {}
json_files = glob.glob("data\\*.json")
for files in json_files:
    with open(files) as input_file:
        jsondat=json.load(input_file)

    review_text = ""
    for content in jsondat['Reviews']:
        review_text += content['Content'].encode("utf-8")
    review_text = review_text.replace("."," ")
    
    # Strip out punctuation and convert the words to all lowercase (to make matching easier to the stop-words).  
    review_text_split = review_text.split(" ")
    rts_temp = []
    for word in review_text_split:
        rts_temp.append(re.sub(r'[^\w\s]|\d','',stem(word.lower())))
    review_text_split = rts_temp

    hotel_descriptors = []
    for rts_words in review_text_split:
        if ((rts_words in remove_words_temp) == False):
            if rts_words != "":
                hotel_descriptors.append(rts_words)
                
    descriptor_count = [[x,hotel_descriptors.count(x)] for x in set(hotel_descriptors)]

    entry2 = {jsondat['HotelInfo']['HotelID']: descriptor_count}
    hotWords.update(entry2)

# %%
hotWords
# Out:
# {u'100506': [['hampton', 1],
#   ['forget', 1],
#   ['skip', 1],
#   ['lack', 1],
#   ['rod', 1],
#   ['catch', 2],
#   ['niec', 1],
#   ['sleep', 15],
#   ['ice', 3],
#   ['go', 14],
#   ['follow', 1],
#   ['chair', 1],
#   ['hate', 1],
#   ['carpet', 14],
#   ['kitchenett', 1],
#   ['airfar', 1],
#   ['decid', 3],
#   ['lean', 1],
#   ['secur', 1],
#   ['million', 1],
#   ['monaco', 1],
#   ['tv', 11],
#   ['embarras', 1],
#   ['elsewher', 1],
#   ['disgusting', 1],
#   ['stores', 1],
#   ['finally', 1],
#   ['th', 9],
#   ['late', 2],
#   ['larg', 1],
#   ['pride', 1],
#   ['worth', 1],
#   ['sent', 1],
#   ['winfrey', 1],
#   ['sound', 4],
#   ['file', 1],
#   ['woman', 2],
#   ['everi', 5],
#   ['risk', 1],
#   ['far', 3],
#   ['desirable', 2],
#   ['checkin', 1],
#   ['bedrooms', 1],
#   ['account', 1],
#   ['choice', 1],
#   ['worst', 2],
#   ['updates', 1],
#   ['fall', 5],
#   ['veri', 28],
#   ['luxury', 2],
#   ['difference', 1],
#   ['strang', 1],
#   ['minute', 1],
#   ['cool', 2],
#   ['tri', 5],
#   ['disgrac', 1],
#   ['hour', 6],
#   ['fantast', 1],
#   ['level', 2],
#   ['joel', 1],
#   ['shock', 1],
#   ['list', 2],
#   ['suffoc', 1],
#   ['condtion', 1],
#   ['adjust', 1],
#   ['subway', 1],
#   ['quick', 1],
#   ['guy', 2],
#   ['clothes', 1],
#   ['enjoy', 4],
#   ['rusti', 1],
#   ['dinners', 1],
#   ['fortun', 1],
#   ['picket', 1],
#   ['tired', 1],
#   ['payed', 1],
#   ['okay', 2],
#   ['direct', 3],
#   ['past', 2],
#   ['religi', 1],
#   ['second', 4],
#   ['street', 11],
#   ['worn', 1],
#   ['nbc', 1],
#   ['run', 5],
#   ['liner', 1],
#   ['telephon', 1],
#   ['flower', 1],
#   ['shining', 1],
#   ['even', 20],
#   ['will', 14],
#   ['abc', 1],
#   ['appear', 1],
#   ['compar', 2],
#   ['chicago', 1],
#   ['repli', 1],
#   ['slight', 2],
#   ['abl', 1],
#   ['find', 7],
#   ['unhelpful', 1],
#   ['hungry', 2],
#   ['frank', 1],
#   ['new', 1],
#   ['appeal', 1],
#   ['ever', 8],
#   ['except', 1],
#   ['sofa', 2],
#   ['told', 7],
#   ['cleaner', 1],
#   ['disappoint', 2],
#   ['full', 5],
#   ['pressur', 1],
#   ['leg', 1],
#   ['pacif', 1],
#   ['clerk', 2],
#   ['never', 10],
#   ['water', 6],
#   ['ramp', 1],
#   ['aircondit', 1],
#   ['middl', 1],
#   ['sink', 3],
#   ['oldfashion', 1],
#   ['based', 1],
#   ['sinc', 4],
#   ['valu', 2],
#   ['wait', 2],
#   ['buck', 2],
#   ['great', 18],
#   ['pretti', 4],
#   ['ahead', 1],
#   ['broken', 2],
#   ['aweful', 1],
#   ['anymor', 1],
#   ['vacat', 1],
#   ['alaska', 3],
#   ['creepy', 2],
#   ['observ', 1],
#   ['credit', 2],
#   ['amount', 2],
#   ['smoke', 1],
#   ['pick', 2],
#   ['real', 1],
#   ['extrem', 3],
#   ['chang', 1],
#   ['sightse', 2],
#   ['pillow', 4],
#   ['creepi', 1],
#   ['conditioning', 1],
#   ['beautiful', 1],
#   ['imposs', 1],
#   ['love', 9],
#   ['extra', 3],
#   ['attend', 3],
#   ['transit', 1],
#   ['advisor', 1],
#   ['ratestay', 1],
#   ['bathtoilet', 1],
#   ['avenu', 1],
#   ['put', 3],
#   ['attitud', 1],
#   ['cons', 1],
#   ['inform', 1],
#   ['seattl', 32],
#   ['famili', 4],
#   ['fake', 1],
#   ['crime', 1],
#   ['establish', 1],
#   ['airconditioning', 1],
#   ['select', 1],
#   ['hotels', 1],
#   ['use', 8],
#   ['nighlif', 1],
#   ['spoke', 1],
#   ['comments', 1],
#   ['memori', 1],
#   ['perk', 1],
#   ['doubl', 2],
#   ['visit', 1],
#   ['two', 11],
#   ['next', 8],
#   ['websit', 4],
#   ['live', 1],
#   ['camera', 1],
#   ['morn', 3],
#   ['ranksmel', 1],
#   ['recommend', 4],
#   ['taken', 2],
#   ['black', 1],
#   ['imag', 1],
#   ['care', 5],
#   ['tell', 3],
#   ['today', 1],
#   ['phone', 1],
#   ['sort', 4],
#   ['entrance', 1],
#   ['expedia', 1],
#   ['door', 5],
#   ['dialup', 1],
#   ['name', 2],
#   ['relax', 3],
#   ['afford', 1],
#   ['peopl', 5],
#   ['relat', 1],
#   ['due', 5],
#   ['funki', 1],
#   ['notic', 1],
#   ['downtown', 13],
#   ['restaurant', 1],
#   ['stick', 1],
#   ['excellent', 1],
#   ['rendered', 1],
#   ['central', 3],
#   ['hole', 7],
#   ['hold', 3],
#   ['outdated', 1],
#   ['bill', 1],
#   ['town', 2],
#   ['none', 3],
#   ['room', 91],
#   ['valuabl', 1],
#   ['heard', 1],
#   ['tunnel', 2],
#   ['setup', 1],
#   ['work', 12],
#   ['breakfast', 4],
#   ['everythinhg', 1],
#   ['wors', 5],
#   ['obvious', 4],
#   ['thin', 2],
#   ['learn', 2],
#   ['star', 2],
#   ['control', 1],
#   ['heart', 1],
#   ['august', 1],
#   ['plaza', 1],
#   ['explor', 1],
#   ['give', 6],
#   ['lock', 2],
#   ['tax', 1],
#   ['ps', 1],
#   ['indic', 1],
#   ['high', 2],
#   ['luggag', 3],
#   ['crazi', 1],
#   ['liter', 2],
#   ['unavail', 1],
#   ['want', 15],
#   ['basebal', 1],
#   ['touristing', 1],
#   ['drive', 1],
#   ['times', 1],
#   ['attract', 3],
#   ['creas', 1],
#   ['huge', 2],
#   ['available', 1],
#   ['cours', 1],
#   ['end', 1],
#   ['sit', 3],
#   ['rather', 2],
#   ['anoth', 4],
#   ['travel', 6],
#   ['comfort', 8],
#   ['europ', 1],
#   ['machine', 1],
#   ['musti', 1],
#   ['hot', 5],
#   ['actual', 1],
#   ['pure', 1],
#   ['scrambl', 1],
#   ['answer', 2],
#   ['instead', 1],
#   ['microwave', 1],
#   ['panic', 1],
#   ['needl', 1],
#   ['pizza', 1],
#   ['mould', 1],
#   ['roach', 1],
#   ['outsid', 2],
#   ['rude', 2],
#   ['mess', 1],
#   ['stop', 5],
#   ['dive', 2],
#   ['filthi', 3],
#   ['internet', 6],
#   ['spot', 1],
#   ['reflect', 1],
#   ['befor', 11],
#   ['modest', 1],
#   ['drink', 1],
#   ['orangemaroonish', 1],
#   ['date', 2],
#   ['acommod', 1],
#   ['suck', 1],
#   ['cheaper', 1],
#   ['marriott', 1],
#   ['man', 1],
#   ['short', 1],
#   ['attempt', 1],
#   ['neck', 1],
#   ['third', 1],
#   ['somethig', 1],
#   ['light', 8],
#   ['conduc', 1],
#   ['wobbl', 2],
#   ['overnight', 2],
#   ['fine', 1],
#   ['scare', 1],
#   ['mislead', 2],
#   ['linen', 1],
#   ['truck', 2],
#   ['waitress', 1],
#   ['allow', 3],
#   ['enter', 1],
#   ['fan', 2],
#   ['shadi', 1],
#   ['dream', 1],
#   ['order', 1],
#   ['wind', 1],
#   ['refund', 1],
#   ['photoshop', 1],
#   ['infested', 1],
#   ['help', 7],
#   ['office', 1],
#   ['repair', 2],
#   ['move', 4],
#   ['orang', 1],
#   ['becaus', 16],
#   ['years', 1],
#   ['whilst', 2],
#   ['paper', 3],
#   ['affect', 1],
#   ['still', 5],
#   ['vari', 1],
#   ['perfect', 4],
#   ['write', 1],
#   ['cheap', 2],
#   ['thank', 3],
#   ['fit', 3],
#   ['immedi', 1],
#   ['polici', 1],
#   ['comic', 1],
#   ['torn', 1],
#   ['sunday', 1],
#   ['lucki', 1],
#   ['better', 7],
#   ['maid', 2],
#   ['window', 12],
#   ['travelodg', 1],
#   ['stiff', 1],
#   ['attractions', 1],
#   ['smokefree', 1],
#   ['decad', 1],
#   ['endless', 1],
#   ['might', 3],
#   ['againstay', 1],
#   ['recept', 2],
#   ['non', 1],
#   ['good', 10],
#   ['return', 1],
#   ['greater', 1],
#   ['food', 1],
#   ['similar', 2],
#   ['plaster', 1],
#   ['safe', 4],
#   ['cover', 1],
#   ['wast', 1],
#   ['underneath', 1],
#   ['tile', 2],
#   ['bang', 1],
#   ['snowflak', 1],
#   ['vomit', 1],
#   ['kid', 1],
#   ['half', 4],
#   ['foot', 3],
#   ['innoc', 1],
#   ['now', 1],
#   ['day', 16],
#   ['bank', 1],
#   ['dingi', 1],
#   ['easily', 1],
#   ['stated', 1],
#   ['thrill', 1],
#   ['anyth', 4],
#   ['corners', 2],
#   ['drop', 1],
#   ['choiceth', 1],
#   ['dingy', 1],
#   ['accommod', 2],
#   ['alreadi', 2],
#   ['break', 2],
#   ['found', 6],
#   ['went', 4],
#   ['higher', 2],
#   ['meal', 1],
#   ['mean', 6],
#   ['gape', 1],
#   ['weight', 1],
#   ['hallway', 2],
#   ['chunk', 2],
#   ['hard', 4],
#   ['yeah', 1],
#   ['terrifi', 2],
#   ['realli', 10],
#   ['fairmont', 1],
#   ['finish', 1],
#   ['expect', 6],
#   ['horribl', 4],
#   ['suite', 1],
#   ['prostitut', 1],
#   ['furniture', 1],
#   ['tatti', 1],
#   ['saturday', 1],
#   ['special', 1],
#   ['hostel', 2],
#   ['depress', 3],
#   ['massiv', 1],
#   ['safeti', 2],
#   ['network', 2],
#   ['space', 2],
#   ['linens', 1],
#   ['motel', 4],
#   ['may', 2],
#   ['suitabl', 1],
#   ['peeling', 1],
#   ['print', 1],
#   ['got', 11],
#   ['defens', 1],
#   ['duct', 3],
#   ['assist', 1],
#   ['insid', 2],
#   ['dirt', 1],
#   ['scumbag', 1],
#   ['nightmar', 3],
#   ['friday', 2],
#   ['differ', 2],
#   ['free', 6],
#   ['standard', 1],
#   ['pleasant', 3],
#   ['small', 5],
#   ['reason', 3],
#   ['base', 2],
#   ['believ', 3],
#   ['tempt', 1],
#   ['ask', 8],
#   ['embarrass', 1],
#   ['anyhow', 1],
#   ['upon', 5],
#   ['card', 1],
#   ['basi', 2],
#   ['hotelveri', 1],
#   ['flush', 2],
#   ['miss', 1],
#   ['pictur', 4],
#   ['terrible', 2],
#   ['refus', 2],
#   ['keep', 3],
#   ['thing', 14],
#   ['funky', 1],
#   ['afternoon', 1],
#   ['place', 35],
#   ['unabl', 1],
#   ['w', 2],
#   ['enough', 3],
#   ['router', 1],
#   ['loud', 4],
#   ['think', 9],
#   ['frequent', 1],
#   ['first', 4],
#   ['blind', 1],
#   ['major', 1],
#   ['suspend', 1],
#   ['student', 1],
#   ['feel', 6],
#   ['frill', 1],
#   ['wave', 1],
#   ['qualiti', 2],
#   ['number', 1],
#   ['rank', 1],
#   ['one', 34],
#   ['channels', 1],
#   ['reopen', 1],
#   ['floors', 2],
#   ['elevator', 2],
#   ['expir', 1],
#   ['disembark', 1],
#   ['ring', 2],
#   ['agre', 1],
#   ['open', 9],
#   ['size', 1],
#   ['min', 1],
#   ['given', 1],
#   ['ancient', 1],
#   ['sheet', 5],
#   ['fair', 1],
#   ['service', 1],
#   ['citi', 4],
#   ['bite', 1],
#   ['slept', 2],
#   ['sometim', 2],
#   ['least', 3],
#   ['plastic', 1],
#   ['paint', 2],
#   ['stori', 2],
#   ['station', 2],
#   ['breez', 1],
#   ['convention', 1],
#   ['white', 1],
#   ['conveni', 4],
#   ['really', 1],
#   ['final', 1],
#   ['friend', 16],
#   ['attach', 1],
#   ['luckili', 3],
#   ['stomach', 1],
#   ['lot', 4],
#   ['awayth', 1],
#   ['especi', 2],
#   ['juli', 2],
#   ['hotel', 111],
#   ['park', 11],
#   ['took', 5],
#   ['someon', 7],
#   ['part', 2],
#   ['annoy', 1],
#   ['somewhat', 1],
#   ['review', 11],
#   ['kept', 1],
#   ['apologet', 1],
#   ['crawl', 2],
#   ['pancak', 1],
#   ['serv', 1],
#   ['kind', 1],
#   ['unfortunately', 1],
#   ['whenev', 1],
#   ['provid', 3],
#   ['gotten', 1],
#   ['bother', 1],
#   ['uptown', 1],
#   ['rate', 8],
#   ['bed', 16],
#   ['charact', 3],
#   ['shower', 10],
#   ['wrong', 1],
#   ['cost', 6],
#   ['expo', 1],
#   ['store', 3],
#   ['iron', 2],
#   ['aircondition', 1],
#   ['posit', 1],
#   ['asleep', 1],
#   ['minut', 2],
#   ['toward', 1],
#   ['bing', 1],
#   ['bet', 1],
#   ['accomod', 1],
#   ['function', 1],
#   ['nicer', 3],
#   ['terribl', 3],
#   ['hairdryer', 2],
#   ['mind', 3],
#   ['ani', 10],
#   ['spent', 6],
#   ['say', 5],
#   ['infront', 1],
#   ['goodness', 1],
#   ['close', 3],
#   ['need', 8],
#   ['seen', 6],
#   ['seem', 5],
#   ['turn', 2],
#   ['saw', 3],
#   ['remodel', 2],
#   ['option', 1],
#   ['imagin', 1],
#   ['nights', 2],
#   ['squar', 1],
#   ['advic', 1],
#   ['bedspread', 1],
#   ['inexpens', 1],
#   ['troublesom', 1],
#   ['note', 1],
#   ['also', 9],
#   ['lumpi', 1],
#   ['contact', 1],
#   ['take', 3],
#   ['advis', 1],
#   ['sanit', 1],
#   ['green', 1],
#   ['wonder', 4],
#   ['blunt', 1],
#   ['rider', 1],
#   ['channel', 6],
#   ['tourist', 1],
#   ['club', 1],
#   ['therefor', 1],
#   ['play', 1],
#   ['sure', 4],
#   ['unless', 3],
#   ['shade', 1],
#   ['plenti', 2],
#   ['though', 8],
#   ['price', 14],
#   ['knew', 3],
#   ['reach', 1],
#   ['whi', 2],
#   ['paid', 5],
#   ['victoria', 1],
#   ['baseboard', 1],
#   ['arcad', 1],
#   ['said', 7],
#   ['whether', 1],
#   ['plan', 2],
#   ['sheets', 3],
#   ['comparison', 1],
#   ['extermin', 1],
#   ['charg', 3],
#   ['amaz', 2],
#   ['excus', 1],
#   ['pathet', 1],
#   ['windows', 1],
#   ['egg', 1],
#   ['alarm', 1],
#   ['later', 3],
#   ['request', 4],
#   ['dog', 1],
#   ['doe', 2],
#   ['pipe', 3],
#   ['realiz', 1],
#   ['artistic', 1],
#   ['clean', 18],
#   ['link', 1],
#   ['usual', 3],
#   ['scotch', 1],
#   ['someth', 4],
#   ['fact', 5],
#   ['shop', 3],
#   ['toiletries', 1],
#   ['asid', 1],
#   ['shot', 1],
#   ['redecor', 1],
#   ['show', 4],
#   ['getaway', 1],
#   ['opposit', 1],
#   ['consult', 1],
#   ['nicest', 1],
#   ['accommodations', 1],
#   ['guest', 4],
#   ['bring', 2],
#   ['goodbut', 1],
#   ['inconsistent', 1],
#   ['bedroom', 1],
#   ['corner', 3],
#   ['unfinish', 4],
#   ['clock', 1],
#   ['staff', 18],
#   ['absolut', 1],
#   ['onli', 45],
#   ['locat', 24],
#   ['just', 21],
#   ['stair', 3],
#   ['shoe', 2],
#   ['buss', 1],
#   ['weekends', 1],
#   ['restaur', 7],
#   ['bug', 4],
#   ['experenic', 1],
#   ['busi', 6],
#   ['walls', 3],
#   ['disgust', 1],
#   ['photo', 5],
#   ['stain', 6],
#   ['local', 4],
#   ['laptop', 1],
#   ['hope', 1],
#   ['meant', 2],
#   ['custom', 1],
#   ['lobi', 1],
#   ['get', 17],
#   ['beat', 1],
#   ['express', 1],
#   ['watch', 4],
#   ['photograph', 1],
#   ['ceil', 5],
#   ['scurri', 1],
#   ['outlet', 1],
#   ['mention', 4],
#   ['basement', 2],
#   ['report', 1],
#   ['swore', 1],
#   ['suggest', 1],
#   ['edg', 1],
#   ['chanel', 1],
#   ['ghetto', 1],
#   ['wallpap', 4],
#   ['uncomfort', 2],
#   ['bar', 1],
#   ['noises', 2],
#   ['graduat', 2],
#   ['board', 1],
#   ['witha', 1],
#   ['pretzel', 1],
#   ['morning', 2],
#   ['sens', 1],
#   ['twice', 2],
#   ['bad', 5],
#   ['furnish', 1],
#   ['x', 1],
#   ['overpr', 2],
#   ['cri', 1],
#   ['husband', 3],
#   ['view', 1],
#   ['certif', 1],
#   ['btw', 1],
#   ['concert', 1],
#   ['dump', 5],
#   ['job', 2],
#   ['shampoo', 1],
#   ['truli', 1],
#   ['knowledg', 1],
#   ['relief', 2],
#   ['around', 5],
#   ['seat', 1],
#   ['malfunct', 1],
#   ['bare', 3],
#   ['sea', 1],
#   ['parking', 1],
#   ['reserv', 4],
#   ['pillows', 1],
#   ['frustrat', 1],
#   ['mistak', 1],
#   ['best', 2],
#   ['concern', 3],
#   ['project', 1],
#   ['entranc', 1],
#   ['wire', 2],
#   ['televis', 4],
#   ['horrid', 1],
#   ['away', 7],
#   ['easi', 1],
#   ['flop', 1],
#   ['okmi', 1],
#   ['figur', 1],
#   ['anxieti', 1],
#   ['various', 2],
#   ['rail', 2],
#   ['horrible', 1],
#   ['awak', 1],
#   ['dank', 1],
#   ['experi', 7],
#   ['across', 2],
#   ['bought', 1],
#   ['corridors', 1],
#   ['mildew', 1],
#   ['comfi', 2],
#   ['extend', 1],
#   ['amen', 3],
#   ['screen', 2],
#   ['however', 2],
#   ['valuable', 1],
#   ['hill', 1],
#   ['spray', 1],
#   ['entir', 4],
#   ['wear', 1],
#   ['key', 4],
#   ['news', 2],
#   ['tub', 2],
#   ['cities', 1],
#   ['come', 6],
#   ['abomin', 1],
#   ['addit', 1],
#   ['bodi', 1],
#   ['c', 1],
#   ['last', 4],
#   ['wee', 2],
#   ['brown', 1],
#   ['plugin', 1],
#   ['joke', 2],
#   ['ave', 1],
#   ['alon', 1],
#   ['equal', 1],
#   ['drug', 1],
#   ['nearbi', 1],
#   ['tlc', 1],
#   ['etc', 5],
#   ['s', 2],
#   ['agent', 1],
#   ['mani', 2],
#   ['whole', 2],
#   ['afraid', 1],
#   ['unmatch', 1],
#   ['con', 1],
#   ['load', 1],
#   ['vent', 2],
#   ['assur', 1],
#   ['twix', 1],
#   ['can', 14],
#   ['wall', 8],
#   ['stuck', 1],
#   ['arriv', 7],
#   ['walk', 6],
#   ['vend', 1],
#   ['deliv', 1],
#   ['laugh', 1],
#   ['cancel', 1],
#   ['typic', 1],
#   ['speak', 2],
#   ['quit', 6],
#   ['bathroom', 25],
#   ['coupl', 2],
#   ['union', 1],
#   ['decent', 2],
#   ['three', 5],
#   ['empti', 1],
#   ['overal', 1],
#   ['much', 8],
#   ['interest', 1],
#   ['basic', 4],
#   ['curtain', 3],
#   ['thrift', 1],
#   ['nois', 2],
#   ['tini', 4],
#   ['pm', 4],
#   ['adventur', 1],
#   ['flight', 1],
#   ['deeper', 1],
#   ['face', 1],
#   ['crack', 1],
#   ['candybar', 1],
#   ['anywher', 2],
#   ['upgrad', 2],
#   ['mocking', 1],
#   ['lift', 1],
#   ['wake', 1],
#   ['togeth', 2],
#   ['child', 1],
#   ['staruck', 1],
#   ['furnitur', 2],
#   ['rang', 2],
#   ['sad', 1],
#   ['case', 2],
#   ['screens', 1],
#   ['look', 20],
#   ['cbs', 1],
#   ['properti', 1],
#   ['servic', 8],
#   ['nd', 3],
#   ['budget', 1],
#   ['reviewsthey', 1],
#   ['air', 7],
#   ['chalk', 1],
#   ['ugly', 2],
#   ['near', 5],
#   ['ceilings', 1],
#   ['facil', 1],
#   ['abov', 2],
#   ['fault', 1],
#   ['fun', 1],
#   ['cracked', 1],
#   ['loos', 4],
#   ['mangeran', 1],
#   ['cart', 2],
#   ['againthi', 1],
#   ['layer', 1],
#   ['garag', 4],
#   ['bathrooms', 1],
#   ['bedsheet', 1],
#   ['almost', 3],
#   ['centr', 1],
#   ['indowntown', 1],
#   ['downton', 1],
#   ['worri', 2],
#   ['iv', 6],
#   ['unclean', 1],
#   ['shame', 2],
#   ['shoddi', 1],
#   ['transom', 1],
#   ['partner', 1],
#   ['seattle', 4],
#   ['kettl', 1],
#   ['sever', 3],
#   ['elder', 1],
#   ['gone', 1],
#   ['facet', 1],
#   ['decor', 7],
#   ['ingrain', 1],
#   ['doctor', 1],
#   ['pay', 8],
#   ['make', 5],
#   ['belong', 2],
#   ['wound', 1],
#   ['airport', 2],
#   ['trip', 4],
#   ['member', 1],
#   ['preserv', 1],
#   ['blanket', 1],
#   ['shag', 2],
#   ['inch', 1],
#   ['eventu', 2],
#   ['complet', 1],
#   ['week', 2],
#   ['exhaust', 3],
#   ['clear', 1],
#   ['oil', 1],
#   ['barefoot', 1],
#   ['screw', 1],
#   ['browndark', 1],
#   ['impass', 1],
#   ['hang', 2],
#   ['lobbi', 7],
#   ['coffe', 3],
#   ['piec', 1],
#   ['rais', 1],
#   ['idea', 1],
#   ['ownership', 2],
#   ['dust', 2],
#   ['build', 2],
#   ['vaniti', 1],
#   ['lobby', 3],
#   ['recent', 1],
#   ['dark', 5],
#   ['lower', 1],
#   ['rip', 1],
#   ['reliev', 1],
#   ['bewar', 1],
#   ['choos', 5],
#   ['elderly', 1],
#   ['floormat', 1],
#   ['pit', 1],
#   ['nonetheless', 1],
#   ['sirens', 1],
#   ['game', 2],
#   ['deal', 2],
#   ['thought', 3],
#   ['person', 3],
#   ['anim', 1],
#   ['without', 4],
#   ['expens', 2],
#   ['elev', 10],
#   ['english', 1],
#   ['toiletri', 1],
#   ['everyth', 3],
#   ['otherwise', 1],
#   ['vacanc', 1],
#   ['spend', 4],
#   ['left', 4],
#   ['taxi', 1],
#   ['summer', 1],
#   ['distanc', 3],
#   ['identifi', 1],
#   ['staircas', 1],
#   ['less', 4],
#   ['yea', 1],
#   ['money', 7],
#   ['somehwer', 1],
#   ['sights', 1],
#   ['rest', 2],
#   ['detail', 2],
#   ['rodent', 1],
#   ['front', 6],
#   ['rooms', 3],
#   ['human', 2],
#   ['noir', 1],
#   ['yes', 4],
#   ['inaudible', 1],
#   ['yet', 2],
#   ['languag', 1],
#   ['previous', 9],
#   ['rundown', 1],
#   ['web', 1],
#   ['generous', 1],
#   ['hazmat', 1],
#   ['mehotel', 1],
#   ['expos', 2],
#   ['la', 1],
#   ['point', 1],
#   ['character', 1],
#   ['reccomend', 1],
#   ['littl', 7],
#   ['hall', 1],
#   ['color', 3],
#   ['add', 1],
#   ['spread', 1],
#   ['location', 3],
#   ['tring', 1],
#   ['els', 7],
#   ['save', 1],
#   ['match', 1],
#   ['useless', 1],
#   ['bin', 1],
#   ['ream', 1],
#   ['complaint', 1],
#   ['sick', 1],
#   ['read', 4],
#   ['big', 3],
#   ['regard', 1],
#   ['possible', 1],
#   ['revamp', 1],
#   ['enthusiastically', 1],
#   ['haul', 1],
#   ['dryer', 1],
#   ...],
#  u'1217974': [['shop', 1],
#   ['gorgeous', 1],
#   ['help', 1],
#   ['knowledg', 1],
#   ['washington', 1],
#   ['deca', 2],
#   ['iv', 1],
#   ['mile', 1],
#   ['seattl', 2],
#   ['explor', 2],
#   ['year', 1],
#   ['home', 1],
#   ['u', 1],
#   ['sever', 2],
#   ['staff', 1],
#   ['decor', 1],
#   ['locat', 1],
#   ['district', 1],
#   ['area', 4],
#   ['goe', 1],
#   ['travel', 1],
#   ['univers', 1],
#   ['visit', 1],
#   ['restaur', 1],
#   ['alway', 1],
#   ['way', 1],
#   ['intrigu', 1],
#   ['intimon', 1],
#   ['stage', 1],
#   ['friend', 1],
#   ['play', 1],
#   ['within', 1],
#   ['tourist', 1],
#   ['numer', 1],
#   ['familiar', 1],
#   ['hotel', 4],
#   ['eclect', 1],
#   ['trail', 1],
#   ['discov', 1],
#   ['new', 1],
#   ['comfortable', 1],
#   ['room', 1],
#   ['tri', 1],
#   ['replic', 1],
#   ['great', 1],
#   ['theater', 1],
#   ['look', 1],
#   ['stylish', 3],
#   ['university', 1],
#   ['cafes', 1],
#   ['hiker', 1],
#   ['place', 1],
#   ['time', 1],
#   ['found', 1]],
#  u'150849': [['raining', 1],
#   ['prefil', 1],
#   ['foul', 1],
#   ['keno', 2],
#   ['four', 36],
#   ['criter', 3],
#   ['cyprus', 2],
#   ['mucho', 2],
#   ['scenelov', 1],
#   ['electricity', 1],
#   ['snorkleing', 1],
#   ['handshake', 1],
#   ['yourselfdo', 1],
#   ['shiraz', 1],
#   ['itsecond', 1],
#   ['digit', 6],
#   ['oceanw', 1],
#   ['delt', 2],
#   ['screaming', 2],
#   ['showroom', 1],
#   ['disturb', 6],
#   ['clientell', 2],
#   ['prize', 5],
#   ['wooden', 5],
#   ['wednesday', 7],
#   ['altagracia', 1],
#   ['yuckth', 1],
#   ['specialties', 1],
#   ['crotch', 1],
#   ['intens', 3],
#   ['cheeto', 1],
#   ['merengue', 1],
#   ['bbqs', 1],
#   ['rusti', 4],
#   ['tired', 3],
#   ['miller', 1],
#   ['seper', 9],
#   ['phraseshola', 1],
#   ['second', 80],
#   ['partylunch', 1],
#   ['thunder', 1],
#   ['cooking', 1],
#   ['fingers', 1],
#   ['immodiumkeopect', 1],
#   ['getawayth', 1],
#   ['wowth', 1],
#   ['hero', 1],
#   ['holdiay', 1],
#   ['remeb', 1],
#   ['ivsit', 1],
#   ['herd', 2],
#   ['reported', 1],
#   ['anway', 1],
#   ['kids', 16],
#   ['naturel', 1],
#   ['militari', 1],
#   ['k', 14],
#   ['unforgett', 1],
#   ['refinish', 1],
#   ['golden', 4],
#   ['brought', 76],
#   ['sterl', 1],
#   ['stern', 1],
#   ['unit', 12],
#   ['ricoand', 1],
#   ['dnd', 3],
#   ['spoke', 57],
#   ['serviceentertain', 1],
#   ['productsgood', 1],
#   ['music', 45],
#   ['therefore', 2],
#   ['passport', 3],
#   ['centr', 6],
#   ['resortwond', 1],
#   ['females', 1],
#   ['relax', 147],
#   ['relat', 6],
#   ['hols', 1],
#   ['yahoo', 2],
#   ['notic', 57],
#   ['hurt', 8],
#   ['glass', 44],
#   ['harmless', 1],
#   ['holi', 3],
#   ['desper', 4],
#   ['occasionwhen', 1],
#   ['hole', 13],
#   ['hold', 12],
#   ['unpack', 5],
#   ['hola', 11],
#   ['accid', 2],
#   ['blade', 3],
#   ['wworld', 1],
#   ['example', 8],
#   ['melons', 1],
#   ['omelett', 5],
#   ['omelets', 1],
#   ['edibl', 4],
#   ['calories', 2],
#   ['household', 1],
#   ['organized', 2],
#   ['okcould', 1],
#   ['caution', 7],
#   ['outdoorsstaff', 1],
#   ['want', 454],
#   ['hod', 1],
#   ['poverty', 2],
#   ['complaining', 4],
#   ['travel', 256],
#   ['copious', 1],
#   ['classifi', 1],
#   ['revisit', 3],
#   ['machine', 1],
#   ['hot', 163],
#   ['hor', 1],
#   ['hop', 3],
#   ['stickup', 1],
#   ['yum', 3],
#   ['shrug', 3],
#   ['perspect', 2],
#   ['stuffexcel', 1],
#   ['greeeeaaaaat', 1],
#   ['beauty', 1],
#   ['cuisine', 1],
#   ['replishened', 1],
#   ['wrong', 35],
#   ['beauti', 265],
#   ['spanishwhich', 1],
#   ['crevic', 1],
#   ['activitiesentertain', 1],
#   ['vicin', 1],
#   ['revolv', 1],
#   ['baggage', 2],
#   ['someplac', 2],
#   ['wing', 3],
#   ['wind', 19],
#   ['wine', 54],
#   ['feedback', 3],
#   ['travelsfantastic', 1],
#   ['backwhat', 1],
#   ['thousands', 1],
#   ['lampshades', 1],
#   ['affect', 10],
#   ['vari', 13],
#   ['stripteaselik', 1],
#   ['meno', 1],
#   ['fit', 23],
#   ['entertei', 1],
#   ['frst', 1],
#   ['fix', 29],
#   ['witrh', 1],
#   ['viewabl', 1],
#   ['thedrink', 1],
#   ['hidden', 2],
#   ['fin', 1],
#   ['easier', 8],
#   ['wouldt', 2],
#   ['slate', 1],
#   ['carinean', 1],
#   ['basics', 2],
#   ['beaut', 1],
#   ['schools', 1],
#   ['blink', 1],
#   ['galenjoy', 1],
#   ['headboard', 1],
#   ['rumour', 1],
#   ['dayamaz', 1],
#   ['piscinitafantastiqu', 1],
#   ['arrog', 1],
#   ['timeour', 1],
#   ['accommod', 16],
#   ['spotless', 31],
#   ['whim', 1],
#   ['ribey', 3],
#   ['amatuerish', 1],
#   ['commiss', 3],
#   ['expectednegatives', 1],
#   ['whip', 1],
#   ['sincerelychrisharrison', 1],
#   ['ironboard', 1],
#   ['rr', 1],
#   ['michiganrelax', 1],
#   ['mayan', 8],
#   ['rd', 27],
#   ['re', 3],
#   ['adapt', 16],
#   ['rb', 1],
#   ['rm', 1],
#   ['rn', 1],
#   ['ro', 1],
#   ['maleencantada', 1],
#   ['jawanna', 2],
#   ['navig', 1],
#   ['nightmar', 2],
#   ['waitersmaidsbar', 1],
#   ['returning', 1],
#   ['mamajuanna', 1],
#   ['registr', 1],
#   ['allerg', 1],
#   ['speedo', 12],
#   ['ate', 107],
#   ['speedi', 4],
#   ['georgous', 2],
#   ['atm', 10],
#   ['atv', 2],
#   ['att', 1],
#   ['unabl', 4],
#   ['resortfood', 1],
#   ['confus', 11],
#   ['apercu', 1],
#   ['shopper', 1],
#   ['mingl', 3],
#   ['wast', 14],
#   ['channels', 2],
#   ['wash', 40],
#   ['spinning', 1],
#   ['wasn', 6],
#   ['wasa', 2],
#   ['bitten', 4],
#   ['yousi', 1],
#   ['service', 28],
#   ['lego', 1],
#   ['defnatley', 1],
#   ['staffthomson', 1],
#   ['assort', 3],
#   ['needed', 2],
#   ['master', 2],
#   ['critter', 1],
#   ['euro', 4],
#   ['listen', 17],
#   ['charter', 11],
#   ['bacon', 4],
#   ['recpet', 1],
#   ['oddest', 1],
#   ['crawl', 10],
#   ['picky', 2],
#   ['trek', 2],
#   ['satillit', 1],
#   ['vielen', 1],
#   ['eleg', 2],
#   ['tree', 124],
#   ['holidaysrosi', 1],
#   ['shower', 71],
#   ['pneumonia', 1],
#   ['bearabl', 1],
#   ['shampoos', 3],
#   ['properlybut', 1],
#   ['againeven', 1],
#   ['esta', 1],
#   ['corni', 1],
#   ['runner', 3],
#   ['boston', 3],
#   ['bargainairporthot', 1],
#   ['corny', 2],
#   ['unappet', 1],
#   ['incompat', 1],
#   ['sailed', 1],
#   ['moneyth', 1],
#   ['bellagio', 1],
#   ['maidwhil', 1],
#   ['doors', 1],
#   ['picki', 37],
#   ['shall', 2],
#   ['burdenwowway', 1],
#   ['object', 5],
#   ['staffwer', 1],
#   ['y', 7],
#   ['mouth', 9],
#   ['daywith', 1],
#   ['letter', 4],
#   ['accomodatingand', 1],
#   ['singer', 2],
#   ['stupid', 2],
#   ['grove', 2],
#   ['tast', 84],
#   ['camp', 4],
#   ['gordons', 3],
#   ['hospit', 27],
#   ['dummi', 1],
#   ['walkaround', 1],
#   ['tech', 2],
#   ['despens', 1],
#   ['scream', 14],
#   ['came', 110],
#   ['marvel', 1],
#   ['extyra', 1],
#   ['tequila', 13],
#   ['cheapli', 1],
#   ['dicker', 2],
#   ['unorgan', 1],
#   ['miffedoveral', 1],
#   ['participate', 1],
#   ['hungary', 1],
#   ['mugs', 2],
#   ['lessons', 6],
#   ['busy', 5],
#   ['layout', 12],
#   ['barier', 1],
#   ['heartili', 1],
#   ['menu', 20],
#   ['restaur', 331],
#   ['theme', 45],
#   ['busi', 29],
#   ['bliss', 1],
#   ['thema', 1],
#   ['rice', 14],
#   ['buse', 1],
#   ['plate', 14],
#   ['starneedless', 1],
#   ['plata', 12],
#   ['seclud', 2],
#   ['champaign', 3],
#   ['foremost', 2],
#   ['pocket', 7],
#   ['caribb', 2],
#   ['variaty', 1],
#   ['caribe', 3],
#   ['tipp', 1],
#   ['nylons', 1],
#   ['net', 3],
#   ['saus', 1],
#   ['negativespeopl', 1],
#   ['saut', 1],
#   ['nicely', 1],
#   ['patch', 3],
#   ['sauc', 3],
#   ['englishgermanspanish', 1],
#   ['coloda', 1],
#   ['respond', 1],
#   ['blew', 2],
#   ['disaster', 1],
#   ['fair', 35],
#   ['med', 13],
#   ['padi', 1],
#   ['result', 10],
#   ['respons', 9],
#   ['fail', 3],
#   ['hammer', 3],
#   ['best', 335],
#   ['geriatr', 1],
#   ['figur', 16],
#   ['score', 2],
#   ['femalepor', 1],
#   ['rundown', 2],
#   ['men', 34],
#   ['extend', 1],
#   ['nature', 1],
#   ['smelled', 2],
#   ['fruits', 3],
#   ['kamakazi', 1],
#   ['englishspanish', 1],
#   ['souvenir', 11],
#   ['extens', 12],
#   ['extent', 6],
#   ['toler', 2],
#   ['advertis', 16],
#   ['accident', 2],
#   ['diarrea', 1],
#   ['country', 21],
#   ['adapter', 1],
#   ['piti', 1],
#   ['foudr', 1],
#   ['planned', 1],
#   ['normandy', 2],
#   ['countri', 76],
#   ['vegitation', 1],
#   ['argue', 1],
#   ['connieblueey', 1],
#   ['rehash', 1],
#   ['assur', 17],
#   ['beachi', 1],
#   ['agreat', 1],
#   ['hotelestado', 1],
#   ['exel', 1],
#   ['beachw', 3],
#   ['assum', 5],
#   ['summar', 1],
#   ['duplic', 2],
#   ['fri', 37],
#   ['fro', 1],
#   ['much', 386],
#   ['recomond', 1],
#   ['privilege', 1],
#   ['hesit', 11],
#   ['chavon', 2],
#   ['parasailed', 1],
#   ['life', 39],
#   ['recomend', 8],
#   ['worker', 32],
#   ['facetoface', 1],
#   ['dave', 1],
#   ['lift', 4],
#   ['chile', 1],
#   ['child', 16],
#   ['worked', 3],
#   ['spin', 1],
#   ['hepl', 1],
#   ['chill', 6],
#   ['dayextra', 1],
#   ['breezeth', 1],
#   ['snorkl', 15],
#   ['commerci', 3],
#   ['intak', 1],
#   ['employ', 1],
#   ['backgreat', 3],
#   ['armband', 1],
#   ['elaborate', 1],
#   ['remembering', 1],
#   ['moldy', 2],
#   ['blowdryer', 1],
#   ['gueststh', 1],
#   ['againsav', 1],
#   ['conditioned', 2],
#   ['letdown', 1],
#   ['player', 3],
#   ['conditioner', 1],
#   ['peopleextrem', 1],
#   ['dilut', 1],
#   ['jame', 6],
#   ['things', 8],
#   ['yellow', 4],
#   ['dazzl', 1],
#   ['thingi', 1],
#   ['split', 1],
#   ['babies', 1],
#   ['horsesho', 2],
#   ['costum', 1],
#   ['european', 76],
#   ['boiled', 2],
#   ['tops', 1],
#   ['tobaco', 1],
#   ['refil', 25],
#   ['fullatencion', 1],
#   ['supper', 1],
#   ['tuna', 1],
#   ['cocoa', 1],
#   ['secondfloor', 1],
#   ['nibbl', 1],
#   ['satisfait', 1],
#   ['lucas', 2],
#   ['bewar', 18],
#   ['burgers', 3],
#   ['disguist', 2],
#   ['sitebi', 1],
#   ['takenaft', 1],
#   ['maketh', 1],
#   ['placewond', 1],
#   ['sleepi', 2],
#   ['previous', 53],
#   ['sleepdin', 1],
#   ['ham', 4],
#   ['easi', 33],
#   ['barrooms', 1],
#   ['lumpi', 1],
#   ['easy', 6],
#   ['prison', 1],
#   ['hat', 8],
#   ['sanit', 7],
#   ['preserv', 2],
#   ['possible', 3],
#   ['awhile', 1],
#   ['shadow', 1],
#   ['measur', 2],
#   ['nusianc', 1],
#   ['specif', 16],
#   ['likewhat', 1],
#   ['remind', 11],
#   ['steps', 2],
#   ['bobbi', 1],
#   ['usadont', 1],
#   ['ola', 2],
#   ['right', 140],
#   ['old', 112],
#   ['crowd', 48],
#   ['people', 29],
#   ['weds', 1],
#   ['socialis', 1],
#   ['higherup', 1],
#   ['bottom', 18],
#   ['condid', 1],
#   ['fob', 3],
#   ['treadmill', 2],
#   ['stingray', 8],
#   ['againani', 1],
#   ['yearawesom', 1],
#   ['diarreah', 2],
#   ['sensibl', 1],
#   ['binder', 1],
#   ['memorable', 2],
#   ['theleft', 1],
#   ['dollars', 4],
#   ['dannyboy', 1],
#   ['o', 19],
#   ['notsogreat', 1],
#   ['repellent', 1],
#   ['coars', 1],
#   ['shopswim', 1],
#   ['carryon', 4],
#   ['soi', 1],
#   ['honeymoon', 28],
#   ['barsnackbar', 1],
#   ['soo', 3],
#   ['son', 37],
#   ['creativ', 2],
#   ['sor', 1],
#   ['sou', 1],
#   ['drinksyou', 1],
#   ['wrap', 7],
#   ['ppol', 2],
#   ['allinclus', 25],
#   ['suffici', 4],
#   ['support', 1],
#   ['constantly', 2],
#   ['happi', 124],
#   ['avail', 73],
#   ['width', 1],
#   ['selfserv', 1],
#   ['acknowledg', 3],
#   ['call', 147],
#   ['fabuleux', 1],
#   ['happy', 8],
#   ['headach', 1],
#   ['offer', 81],
#   ['doorit', 1],
#   ['armi', 2],
#   ['gravol', 3],
#   ['understandable', 1],
#   ['airconditiong', 2],
#   ['inside', 3],
#   ['dominicans', 1],
#   ['nicest', 26],
#   ['pesos', 4],
#   ['palm', 151],
#   ['itiner', 1],
#   ['passenger', 1],
#   ['proud', 2],
#   ['minibar', 28],
#   ['exist', 4],
#   ['bedsheet', 3],
#   ['melao', 4],
#   ['hollar', 1],
#   ['paperwork', 1],
#   ['crossdress', 1],
#   ['dealer', 4],
#   ['warma', 1],
#   ['smelt', 1],
#   ['floor', 92],
#   ['flood', 3],
#   ['republic', 6],
#   ['pregnanc', 1],
#   ['smell', 81],
#   ['roll', 11],
#   ['greenery', 1],
#   ['intend', 3],
#   ['palms', 1],
#   ['greeneri', 1],
#   ['atmostphere', 1],
#   ['smelling', 1],
#   ['mirando', 1],
#   ['relaxamazing', 1],
#   ['domingo', 12],
#   ['lamin', 1],
#   ['time', 789],
#   ['push', 27],
#   ['bfast', 1],
#   ['cincinnati', 2],
#   ['chain', 16],
#   ['depand', 1],
#   ['reviewers', 1],
#   ['qualm', 1],
#   ['terible', 1],
#   ['jeebi', 1],
#   ['chair', 129],
#   ['chais', 1],
#   ['midst', 1],
#   ['decid', 56],
#   ['uneven', 2],
#   ['indivu', 1],
#   ['werath', 1],
#   ['veg', 2],
#   ['decis', 6],
#   ['larg', 75],
#   ['excursionshop', 1],
#   ['comuc', 1],
#   ['bogus', 1],
#   ['juanaitalian', 1],
#   ['prepaid', 2],
#   ['choice', 10],
#   ['hardwork', 3],
#   ['embark', 1],
#   ['infectiouslastly', 1],
#   ['exact', 26],
#   ['minute', 5],
#   ['mahi', 2],
#   ['tear', 2],
#   ['leftov', 3],
#   ['leave', 5],
#   ['ixtapa', 1],
#   ['subway', 1],
#   ['teal', 1],
#   ['team', 112],
#   ['cooki', 1],
#   ['youask', 1],
#   ['prevent', 6],
#   ['fingur', 1],
#   ['claritylack', 1],
#   ['sigh', 1],
#   ['compens', 4],
#   ['boca', 1],
#   ['sign', 24],
#   ['shirts', 4],
#   ['nightim', 1],
#   ['goes', 1],
#   ['stuffbeach', 1],
#   ['cleanliness', 3],
#   ['melt', 7],
#   ['current', 3],
#   ['bargin', 5],
#   ['mell', 1],
#   ['fifti', 1],
#   ['boost', 1],
#   ['honour', 1],
#   ['aircondit', 12],
#   ['upgrade', 1],
#   ['address', 3],
#   ['poolsi', 1],
#   ['righttips', 1],
#   ['along', 84],
#   ['arch', 1],
#   ['breezeplenti', 1],
#   ['brilliant', 22],
#   ['ourself', 1],
#   ['queue', 3],
#   ['accomplished', 1],
#   ['barvaro', 1],
#   ['dusti', 2],
#   ['colonni', 1],
#   ['ourselv', 14],
#   ['lova', 1],
#   ['pepto', 13],
#   ['tasks', 1],
#   ['love', 302],
#   ['rambl', 1],
#   ['prefer', 43],
#   ['bananaloc', 1],
#   ['livli', 1],
#   ['aweinspir', 1],
#   ['fake', 5],
#   ['instal', 2],
#   ['anounc', 1],
#   ['bloodi', 1],
#   ['applevac', 1],
#   ['courteoushad', 1],
#   ['fresher', 2],
#   ['working', 3],
#   ['positive', 2],
#   ['hyatt', 2],
#   ['films', 1],
#   ['allinall', 1],
#   ['servicehough', 1],
#   ['afford', 10],
#   ['peopl', 623],
#   ['enhanc', 2],
#   ['everywhere', 14],
#   ['easiest', 1],
#   ['anything', 7],
#   ['pretend', 4],
#   ['fli', 25],
#   ['vega', 8],
#   ['lobyexcelent', 1],
#   ['whatev', 13],
#   ['following', 1],
#   ['problemat', 1],
#   ['lobbygreat', 1],
#   ['awesome', 13],
#   ['stoli', 1],
#   ['usno', 1],
#   ['mediterraneansteak', 1],
#   ['recycl', 2],
#   ['stole', 2],
#   ['drama', 1],
#   ['winter', 2],
#   ['savor', 1],
#   ['mustymoldi', 1],
#   ['goodd', 1],
#   ['blasting', 1],
#   ['spot', 40],
#   ['rigoroberto', 1],
#   ['semifin', 1],
#   ['laundri', 4],
#   ['date', 20],
#   ['dispensor', 4],
#   ['filthy', 1],
#   ['paridis', 1],
#   ['stress', 4],
#   ['wheelchair', 5],
#   ['sp', 4],
#   ['st', 25],
#   ['kieron', 1],
#   ['mango', 6],
#   ['truck', 48],
#   ['swollen', 1],
#   ['sc', 1],
#   ['hol', 8],
#   ['se', 1],
#   ['footstep', 1],
#   ['thomson', 52],
#   ['course', 8],
#   ['pickyth', 1],
#   ['beachther', 1],
#   ['yeard', 1],
#   ['hooneymoon', 1],
#   ['beachthey', 1],
#   ['tore', 1],
#   ['jig', 1],
#   ['avid', 1],
#   ['overhaul', 1],
#   ['thumb', 5],
#   ['cleanest', 3],
#   ['torn', 1],
#   ['parades', 1],
#   ['limbo', 1],
#   ['exot', 3],
#   ['nation', 5],
#   ['arriving', 3],
#   ['servers', 1],
#   ['ahaha', 1],
#   ['ketchup', 2],
#   ['didn', 37],
#   ['roasts', 1],
#   ['separ', 14],
#   ['fabian', 1],
#   ['bowling', 1],
#   ['anymor', 3],
#   ['updat', 6],
#   ['trivail', 1],
#   ['sponsor', 1],
#   ['prostitut', 2],
#   ['amaretto', 1],
#   ['salads', 10],
#   ['neighbourhood', 1],
#   ['crowding', 1],
#   ['troll', 1],
#   ['naked', 1],
#   ['matteress', 1],
#   ['bathrob', 1],
#   ['europeanstyl', 1],
#   ['wiskey', 1],
#   ['internet', 16],
#   ['definitelyth', 1],
#   ['occupi', 7],
#   ['bumpi', 10],
#   ['domest', 2],
#   ['allparadis', 1],
#   ['disrespect', 2],
#   ['bumps', 1],
#   ['sanoa', 3],
#   ['mime', 2],
#   ['besides', 1],
#   ['grandma', 1],
#   ['vegetarians', 1],
#   ['unpredict', 1],
#   ['airfar', 1],
#   ['departur', 18],
#   ['puna', 1],
#   ['recom', 1],
#   ['modest', 3],
#   ['recov', 2],
#   ['massive', 1],
#   ['occaision', 1],
#   ['pillowcas', 2],
#   ['oper', 11],
#   ['oni', 1],
#   ['spoken', 7],
#   ['onc', 80],
#   ['one', 841],
#   ['submit', 2],
#   ['spanish', 116],
#   ['open', 116],
#   ['swimup', 14],
#   ['brochur', 14],
#   ['city', 2],
#   ['bismal', 2],
#   ['ukw', 1],
#   ['bite', 14],
#   ['upstair', 1],
#   ['citi', 10],
#   ['shiver', 1],
#   ['draft', 1],
#   ['stuffed', 1],
#   ['acidophyli', 1],
#   ['conveni', 7],
#   ['bits', 1],
#   ['beachgreat', 1],
#   ['reiter', 1],
#   ['starfish', 1],
#   ['provinc', 1],
#   ['mairinarium', 1],
#   ['suit', 41],
#   ['artifact', 1],
#   ['snatch', 1],
#   ['padding', 1],
#   ['ridiculous', 2],
#   ['kidsag', 1],
#   ['boyfriend', 20],
#   ['rival', 3],
#   ['xrays', 1],
#   ['banner', 1],
#   ['future', 1],
#   ['nuisanc', 1],
#   ['russia', 3],
#   ['illness', 3],
#   ['san', 6],
#   ['nicer', 25],
#   ['sag', 2],
#   ['sad', 19],
#   ['say', 312],
#   ['rained', 1],
#   ['sap', 1],
#   ['saw', 97],
#   ['sat', 22],
#   ['danceaft', 1],
#   ['golar', 1],
#   ['sport', 32],
#   ['eveen', 1],
#   ['cigarettes', 1],
#   ['note', 44],
#   ['massg', 1],
#   ['algarve', 1],
#   ['take', 336],
#   ['destroy', 1],
#   ['europeans', 4],
#   ['noth', 135],
#   ['cockaroach', 1],
#   ['dinghies', 1],
#   ['buffer', 1],
#   ['knew', 31],
#   ['buffet', 266],
#   ['waiterappl', 1],
#   ['damage', 1],
#   ['lawn', 1],
#   ['stilts', 1],
#   ['jitteri', 1],
#   ['average', 11],
#   ['sodaw', 1],
#   ['infections', 2],
#   ['sale', 3],
#   ['sodas', 1],
#   ['occidental', 1],
#   ['yucatan', 3],
#   ['bada', 1],
#   ['dolor', 1],
#   ['salt', 4],
#   ['walking', 1],
#   ['personel', 1],
#   ['bathroomroom', 1],
#   ['bright', 8],
#   ['inconsistent', 2],
#   ['dirtybathroom', 1],
#   ['aggressive', 1],
#   ['entertainmentthi', 1],
#   ['unfinish', 1],
#   ['slot', 4],
#   ['slow', 10],
#   ['slop', 1],
#   ['proshop', 1],
#   ['activ', 106],
#   ['sandpap', 1],
#   ['going', 4],
#   ['hockey', 1],
#   ['equipped', 1],
#   ['robe', 2],
#   ['carolina', 1],
#   ['junglether', 1],
#   ['immaculatley', 1],
#   ['goodluck', 2],
#   ['seemless', 1],
#   ['comoverall', 1],
#   ['outlet', 12],
#   ['clearest', 1],
#   ['requir', 19],
#   ['letharg', 1],
#   ['rddollar', 1],
#   ['artist', 4],
#   ['tequilla', 1],
#   ['borrow', 3],
#   ['tenerife', 1],
#   ['workweek', 1],
#   ['tiki', 1],
#   ['luckdisappoint', 1],
#   ['twelv', 2],
#   ['eyeopen', 2],
#   ['organis', 7],
#   ['counrty', 1],
#   ['basicali', 1],
#   ['tortilla', 1],
#   ['trya', 1],
#   ['xmas', 1],
#   ['noisier', 1],
#   ['espn', 1],
#   ['elsewont', 1],
#   ['masseus', 1],
#   ['misc', 1],
#   ['isabel', 2],
#   ['anyways', 4],
#   ['aprilth', 1],
#   ['hardbr', 1],
#   ['diver', 4],
#   ['moldi', 3],
#   ['annoyingshow', 1],
#   ['enjoyb', 1],
#   ['siter', 1],
#   ['sites', 1],
#   ['manicur', 1],
#   ['goers', 1],
#   ['bureau', 1],
#   ['vender', 2],
#   ['punta', 244],
#   ['assumpt', 1],
#   ['grandpar', 2],
#   ['jobs', 2],
#   ['screen', 7],
#   ['dome', 1],
#   ['supermarket', 1],
#   ['smoothi', 8],
#   ['spare', 3],
#   ['joba', 1],
#   ['jets', 1],
#   ['shortag', 7],
#   ['spark', 1],
#   ['oust', 1],
#   ['gollon', 1],
#   ['many', 3],
#   ['confisc', 1],
#   ['s', 41],
#   ['timesorri', 1],
#   ['mang', 1],
#   ['mani', 246],
#   ['ants', 2],
#   ['republicriu', 1],
#   ['exagger', 2],
#   ['twin', 5],
#   ['anti', 1],
#   ['anth', 1],
#   ['cokes', 1],
#   ['boat', 100],
#   ['cramps', 1],
#   ['plantation', 6],
#   ['stretch', 16],
#   ['west', 4],
#   ['fiveyear', 1],
#   ['vacation', 43],
#   ['breath', 9],
#   ['balconyterrac', 1],
#   ['thousand', 7],
#   ['transper', 1],
#   ['newfieislandgirlhotmail', 1],
#   ['photos', 3],
#   ['former', 2],
#   ['accessth', 1],
#   ['dressi', 1],
#   ['straighten', 4],
#   ['resturant', 1],
#   ['canoes', 3],
#   ['inconsider', 3],
#   ['weaktoo', 1],
#   ['situation', 2],
#   ['ambienc', 2],
#   ['nonmemb', 1],
#   ['convinc', 4],
#   ['dubious', 1],
#   ['fianceprepos', 1],
#   ['bedbathedther', 1],
#   ['atellitetv', 1],
#   ['everday', 1],
#   ['gwv', 1],
#   ['coconuts', 1],
#   ['angentina', 1],
#   ['travellor', 1],
#   ['miscelan', 1],
#   ['singapore', 1],
#   ['cheeri', 1],
#   ['anic', 1],
#   ['ealjuic', 1],
#   ['advicebr', 1],
#   ['hubbi', 1],
#   ['machet', 6],
#   ['veal', 1],
#   ['alfredo', 1],
#   ['hubby', 1],
#   ['vacanc', 1],
#   ['slimi', 2],
#   ['rest', 56],
#   ['steamer', 1],
#   ['resi', 1],
#   ['lizhad', 1],
#   ['concentr', 1],
#   ['indulg', 2],
#   ['littl', 326],
#   ['silver', 1],
#   ...],
#  u'214680': [['showertub', 1],
#   ['four', 2],
#   ['suprisingley', 1],
#   ['sleep', 14],
#   ['trolley', 2],
#   ['accur', 1],
#   ['sorri', 2],
#   ['remodeled', 1],
#   ['buddi', 1],
#   ['sorry', 1],
#   ['worth', 10],
#   ['swivel', 1],
#   ['breathtak', 2],
#   ['everi', 28],
#   ['faboul', 1],
#   ['blanket', 1],
#   ['yellow', 2],
#   ['appar', 1],
#   ['fullsuperlag', 1],
#   ['school', 4],
#   ['kitchenett', 1],
#   ['sunsetloc', 1],
#   ['humidity', 1],
#   ['bodi', 2],
#   ['triumph', 1],
#   ['enjoy', 23],
#   ['tired', 1],
#   ['direct', 13],
#   ['rusty', 1],
#   ['street', 47],
#   ['parter', 1],
#   ['onsit', 1],
#   ['n', 1],
#   ['even', 29],
#   ['theroom', 2],
#   ['hide', 3],
#   ['quamanag', 1],
#   ['sogno', 1],
#   ['new', 18],
#   ['tips', 1],
#   ['ever', 11],
#   ['told', 11],
#   ['apellia', 1],
#   ['never', 26],
#   ['lodg', 1],
#   ['cranin', 1],
#   ['pleasur', 2],
#   ['dry', 1],
#   ['fullalt', 1],
#   ['daughter', 1],
#   ['forum', 1],
#   ['bedding', 1],
#   ['anymor', 1],
#   ['loos', 1],
#   ['dri', 1],
#   ['credit', 1],
#   ['smoke', 2],
#   ['lining', 1],
#   ['darlen', 1],
#   ['fantastic', 2],
#   ['stink', 1],
#   ['julia', 2],
#   ['parkhug', 1],
#   ['avenu', 1],
#   ['attitud', 1],
#   ['total', 7],
#   ['nightclubupstair', 1],
#   ['unit', 2],
#   ['describ', 1],
#   ['leaki', 1],
#   ['dnt', 1],
#   ['music', 3],
#   ['calm', 1],
#   ['recommend', 27],
#   ['accomd', 1],
#   ['type', 2],
#   ['tell', 8],
#   ['sushi', 3],
#   ['relax', 11],
#   ['relat', 6],
#   ['notic', 3],
#   ['glass', 4],
#   ['warm', 4],
#   ['grandfath', 1],
#   ['adult', 1],
#   ['ahidden', 1],
#   ['excellent', 2],
#   ['turtl', 3],
#   ['hole', 1],
#   ['hold', 3],
#   ['must', 6],
#   ['rightw', 1],
#   ['word', 5],
#   ['room', 382],
#   ['viewfriend', 1],
#   ['work', 18],
#   ['worn', 3],
#   ['wors', 2],
#   ['ms', 1],
#   ['example', 2],
#   ['give', 11],
#   ['comfortableth', 1],
#   ['woman', 1],
#   ['buildingsjust', 1],
#   ['want', 49],
#   ['freshen', 1],
#   ['keep', 8],
#   ['attract', 1],
#   ['unforgettable', 1],
#   ['end', 32],
#   ['turn', 6],
#   ['travel', 16],
#   ['corvett', 1],
#   ['amazing', 6],
#   ['confin', 1],
#   ['answer', 3],
#   ['disappoint', 9],
#   ['nicemi', 1],
#   ['beach', 149],
#   ['updat', 4],
#   ['beauty', 1],
#   ['oregonpark', 1],
#   ['earlier', 2],
#   ['befor', 12],
#   ['wrong', 8],
#   ['lay', 2],
#   ['beauti', 18],
#   ['averag', 2],
#   ['keed', 1],
#   ['third', 1],
#   ['pullout', 1],
#   ['greet', 4],
#   ['think', 19],
#   ['receiv', 1],
#   ['maintain', 2],
#   ['environ', 1],
#   ['enter', 5],
#   ['worst', 1],
#   ['pillowcas', 1],
#   ['wind', 3],
#   ['suround', 1],
#   ['deck', 3],
#   ['decentclean', 1],
#   ['bleach', 1],
#   ['tricked', 1],
#   ['japan', 2],
#   ['flexibl', 1],
#   ['ticket', 3],
#   ['gentl', 3],
#   ['fit', 9],
#   ['fix', 9],
#   ['imo', 1],
#   ['crew', 1],
#   ['better', 24],
#   ['offic', 1],
#   ['strand', 1],
#   ['vents', 1],
#   ['weeks', 1],
#   ['fo', 1],
#   ['coffee', 4],
#   ['anim', 1],
#   ['tourist', 3],
#   ['safe', 14],
#   ['break', 4],
#   ['band', 1],
#   ['promis', 2],
#   ['housekeep', 3],
#   ['urmm', 1],
#   ['rental', 3],
#   ['bread', 1],
#   ['dingi', 1],
#   ['choic', 8],
#   ['repaint', 1],
#   ['leonor', 16],
#   ['accommod', 4],
#   ['enjoyif', 1],
#   ['oahu', 10],
#   ['went', 39],
#   ['didntand', 1],
#   ['side', 18],
#   ['mean', 3],
#   ['parkshor', 8],
#   ['navi', 1],
#   ['unscrew', 1],
#   ['forgot', 3],
#   ['dawn', 1],
#   ['saturday', 4],
#   ['hostel', 1],
#   ['network', 1],
#   ['waikikigreat', 1],
#   ['god', 1],
#   ['motel', 6],
#   ['kapiolani', 9],
#   ['thisin', 1],
#   ['rd', 4],
#   ['got', 44],
#   ['beachwireless', 1],
#   ['happenedand', 1],
#   ['situat', 1],
#   ['free', 20],
#   ['standard', 2],
#   ['fring', 1],
#   ['ate', 1],
#   ['argument', 1],
#   ['touristi', 2],
#   ['days', 3],
#   ['takeout', 1],
#   ['confus', 2],
#   ['bite', 1],
#   ['slept', 5],
#   ['dime', 1],
#   ['puck', 2],
#   ['wast', 2],
#   ['wash', 2],
#   ['unlik', 1],
#   ['alreadi', 5],
#   ['messag', 2],
#   ['nhs', 1],
#   ['thick', 1],
#   ['fantast', 18],
#   ['gelber', 1],
#   ['toy', 1],
#   ['service', 4],
#   ['top', 6],
#   ['sometim', 3],
#   ['downsid', 1],
#   ['needed', 3],
#   ['rates', 2],
#   ['breez', 1],
#   ['curtains', 2],
#   ['surfshop', 1],
#   ['gym', 1],
#   ['took', 7],
#   ['honolulu', 21],
#   ['distance', 1],
#   ['silli', 1],
#   ['streeti', 1],
#   ['provid', 5],
#   ['hike', 1],
#   ['tree', 3],
#   ['zero', 2],
#   ['shower', 18],
#   ['matter', 4],
#   ['pooldeck', 1],
#   ['iron', 2],
#   ['spoiled', 1],
#   ['minut', 8],
#   ['saltimbanco', 1],
#   ['mini', 3],
#   ['fashion', 1],
#   ['runner', 1],
#   ['lulu', 19],
#   ['mine', 1],
#   ['spacieus', 1],
#   ['rap', 1],
#   ['seen', 2],
#   ['seem', 8],
#   ['mins', 1],
#   ['boogi', 1],
#   ['qualit', 1],
#   ['scraped', 1],
#   ['luxuri', 4],
#   ['terrif', 3],
#   ['luxury', 1],
#   ['couldbar', 1],
#   ['expens', 6],
#   ['blue', 1],
#   ['jetti', 1],
#   ['plenti', 4],
#   ['though', 19],
#   ['tye', 1],
#   ['himid', 1],
#   ['regular', 1],
#   ['excus', 1],
#   ['waikaii', 1],
#   ['flop', 1],
#   ['metal', 2],
#   ['hospit', 5],
#   ['poolsundeck', 1],
#   ['oahui', 1],
#   ['came', 7],
#   ['bait', 1],
#   ['redecor', 1],
#   ['opposit', 2],
#   ['queen', 1],
#   ['brief', 1],
#   ['prix', 1],
#   ['colors', 1],
#   ['respectfully', 1],
#   ['earth', 1],
#   ['despit', 1],
#   ['nightstands', 1],
#   ['layout', 1],
#   ['heartili', 1],
#   ['menu', 3],
#   ['explain', 3],
#   ['restaur', 23],
#   ['hrs', 3],
#   ['sugar', 1],
#   ['timesth', 1],
#   ['busi', 16],
#   ['disgust', 1],
#   ['hawiian', 2],
#   ['edmonton', 1],
#   ['buse', 3],
#   ['plate', 3],
#   ['klein', 1],
#   ['tilex', 1],
#   ['notfriend', 1],
#   ['de', 1],
#   ['watch', 14],
#   ['stayfantast', 1],
#   ['leisure', 1],
#   ['ceil', 7],
#   ['wakiki', 2],
#   ['supplies', 1],
#   ['report', 2],
#   ['entrynic', 1],
#   ['diaamond', 1],
#   ['bar', 7],
#   ['nonsmoking', 1],
#   ['excel', 10],
#   ['patch', 1],
#   ['bag', 7],
#   ['bad', 15],
#   ['experiencesoh', 1],
#   ['kauai', 1],
#   ['septemb', 1],
#   ['respond', 1],
#   ['blew', 1],
#   ['fair', 3],
#   ['nut', 1],
#   ['radius', 1],
#   ['fail', 2],
#   ['best', 41],
#   ['awar', 3],
#   ['said', 25],
#   ['onto', 2],
#   ['away', 19],
#   ['discoveri', 1],
#   ['figur', 4],
#   ['score', 1],
#   ['extend', 4],
#   ['weak', 1],
#   ['however', 6],
#   ['mackey', 1],
#   ['aquarium', 5],
#   ['news', 1],
#   ['kitchen', 1],
#   ['received', 1],
#   ['easi', 13],
#   ['fault', 2],
#   ['howev', 11],
#   ['youngset', 1],
#   ['brag', 1],
#   ['countri', 1],
#   ['com', 2],
#   ['con', 1],
#   ['xd', 1],
#   ['springi', 1],
#   ['tone', 1],
#   ['toni', 1],
#   ['vicintiy', 1],
#   ['towels', 2],
#   ['creamfil', 1],
#   ['dowsett', 1],
#   ['blonde', 1],
#   ['guid', 1],
#   ['assum', 1],
#   ['speak', 2],
#   ['reciev', 1],
#   ['bathroom', 25],
#   ['nicer', 5],
#   ['three', 6],
#   ['haunama', 1],
#   ['much', 25],
#   ['interest', 2],
#   ['basic', 7],
#   ['hesit', 5],
#   ['website', 1],
#   ['life', 4],
#   ['families', 1],
#   ['recomend', 1],
#   ['relaxing', 1],
#   ['worker', 1],
#   ['chipped', 1],
#   ['ani', 24],
#   ['lift', 2],
#   ['balconyth', 1],
#   ['child', 1],
#   ['catch', 5],
#   ['stayterrif', 1],
#   ['gracious', 1],
#   ['ugli', 2],
#   ['cryingroom', 1],
#   ['adress', 1],
#   ['servic', 31],
#   ['properti', 11],
#   ['air', 15],
#   ['near', 7],
#   ['neat', 1],
#   ['midoctob', 1],
#   ['occas', 1],
#   ['property', 2],
#   ['employees', 1],
#   ['seven', 1],
#   ['garag', 2],
#   ['shebang', 1],
#   ['sticker', 1],
#   ['tabl', 3],
#   ['iv', 10],
#   ['exterior', 1],
#   ['conditioner', 1],
#   ['unforgett', 1],
#   ['sever', 3],
#   ['fridgelocation', 1],
#   ['perform', 1],
#   ['suggest', 4],
#   ['make', 36],
#   ['toaster', 1],
#   ['amount', 2],
#   ['thingi', 1],
#   ['plates', 1],
#   ['locationa', 1],
#   ['complet', 4],
#   ['updated', 1],
#   ['rail', 2],
#   ['hand', 2],
#   ['delight', 2],
#   ['hotelhawaii', 1],
#   ['traffice', 1],
#   ['overr', 1],
#   ['kid', 3],
#   ['butter', 1],
#   ['kept', 6],
#   ['drip', 2],
#   ['ocean', 73],
#   ['tho', 1],
#   ['bedspread', 1],
#   ['greatest', 2],
#   ['mother', 3],
#   ['everyth', 40],
#   ['parkw', 1],
#   ['left', 13],
#   ['just', 85],
#   ['photo', 3],
#   ['laptop', 1],
#   ['fullsupp', 2],
#   ['yes', 13],
#   ['yet', 4],
#   ['previous', 6],
#   ['zoowhat', 1],
#   ['han', 2],
#   ['underneathgreat', 1],
#   ['royal', 1],
#   ['spread', 2],
#   ['board', 4],
#   ['els', 8],
#   ['save', 2],
#   ['plasma', 1],
#   ['gave', 10],
#   ['opt', 2],
#   ['gegenueb', 1],
#   ['mayb', 3],
#   ['memmber', 1],
#   ['coffeebreakfast', 1],
#   ['roach', 1],
#   ['apart', 1],
#   ['brought', 2],
#   ['gift', 1],
#   ['specif', 2],
#   ['cooler', 1],
#   ['negat', 3],
#   ['confid', 1],
#   ['night', 77],
#   ['imagin', 2],
#   ['www', 1],
#   ['right', 80],
#   ['old', 27],
#   ['deal', 14],
#   ['people', 2],
#   ['dead', 1],
#   ['intern', 2],
#   ['doorstep', 1],
#   ['bottom', 2],
#   ['ice', 3],
#   ['everything', 1],
#   ['cityview', 2],
#   ['condit', 9],
#   ['refrigerator', 2],
#   ['mosquito', 1],
#   ['cord', 1],
#   ['peek', 1],
#   ['peel', 2],
#   ['burn', 1],
#   ['vickyandtonyperthaustraliasmal', 1],
#   ['colleg', 1],
#   ['buffet', 1],
#   ['post', 6],
#   ['super', 2],
#   ['spoke', 1],
#   ['plug', 2],
#   ['luau', 1],
#   ['dollars', 1],
#   ['months', 1],
#   ['surround', 3],
#   ['unfortun', 1],
#   ['dinner', 2],
#   ['plus', 5],
#   ['afternoon', 2],
#   ['horizon', 1],
#   ['sept', 1],
#   ['bath', 9],
#   ['froze', 2],
#   ['honeymoon', 7],
#   ['son', 1],
#   ['stop', 14],
#   ['lies', 2],
#   ['opportun', 1],
#   ['storag', 2],
#   ['thanksok', 1],
#   ['crowd', 6],
#   ['frill', 1],
#   ['happi', 4],
#   ['avail', 5],
#   ['reli', 2],
#   ['way', 24],
#   ['creameri', 1],
#   ['call', 17],
#   ['lowest', 1],
#   ['head', 58],
#   ['balconygreat', 2],
#   ['offer', 20],
#   ['poolbeach', 1],
#   ['wireless', 1],
#   ['heat', 2],
#   ['hear', 6],
#   ['refriger', 2],
#   ['true', 6],
#   ['balconyawesom', 1],
#   ['inquir', 1],
#   ['inside', 1],
#   ['bargain', 1],
#   ['hospitalityfrom', 1],
#   ['featur', 1],
#   ['request', 12],
#   ['wboard', 1],
#   ['comfortablepleas', 1],
#   ['shoppingrestaurants', 1],
#   ['exist', 1],
#   ['glanc', 1],
#   ['mold', 5],
#   ['trip', 24],
#   ['floor', 51],
#   ['tip', 4],
#   ['delapad', 1],
#   ['tim', 1],
#   ['smell', 6],
#   ['intend', 2],
#   ['panoram', 1],
#   ['handicap', 1],
#   ['surprise', 2],
#   ['felt', 11],
#   ['update', 1],
#   ['roomoctob', 1],
#   ['fell', 1],
#   ['intent', 1],
#   ['consid', 4],
#   ['minikitchen', 1],
#   ['weekend', 4],
#   ['kalakaua', 2],
#   ['outdat', 1],
#   ['younger', 2],
#   ['longer', 3],
#   ['phone', 8],
#   ['daily', 2],
#   ['beds', 2],
#   ['ignor', 1],
#   ['time', 81],
#   ['push', 1],
#   ['serious', 3],
#   ['daili', 4],
#   ['celebr', 2],
#   ['focus', 1],
#   ['manager', 3],
#   ['mile', 3],
#   ['microwave', 3],
#   ['trashcan', 1],
#   ['chair', 5],
#   ['chais', 1],
#   ['herelov', 1],
#   ['poolsideand', 1],
#   ['decid', 2],
#   ['recommand', 1],
#   ['depend', 4],
#   ['proxim', 2],
#   ['father', 2],
#   ['crater', 2],
#   ['finally', 2],
#   ['brkfst', 1],
#   ['sourc', 1],
#   ['stayi', 1],
#   ['embark', 1],
#   ['enviorn', 1],
#   ['octob', 1],
#   ['join', 2],
#   ['exact', 4],
#   ['cool', 5],
#   ['impressive', 1],
#   ['level', 5],
#   ['die', 1],
#   ['hawaii', 23],
#   ['p', 2],
#   ['soooo', 1],
#   ['subway', 3],
#   ['fabulousconvenient', 1],
#   ['team', 1],
#   ['quick', 10],
#   ['guy', 6],
#   ['dip', 1],
#   ['round', 3],
#   ['cloudi', 1],
#   ['asnic', 1],
#   ['sign', 2],
#   ['everytim', 1],
#   ['roof', 1],
#   ['unbar', 1],
#   ['boats', 1],
#   ['stands', 1],
#   ['repli', 1],
#   ['hadeveryth', 1],
#   ['rollup', 1],
#   ['mall', 1],
#   ['melt', 1],
#   ['meli', 1],
#   ['suspect', 1],
#   ['gazebo', 1],
#   ['clerk', 2],
#   ['perpendicular', 1],
#   ['water', 18],
#   ['entertain', 2],
#   ['restaurantsbut', 1],
#   ['drainag', 1],
#   ['along', 3],
#   ['change', 1],
#   ['wait', 15],
#   ['invis', 1],
#   ['boy', 2],
#   ['invit', 3],
#   ['brilliant', 1],
#   ['bon', 1],
#   ['extrem', 14],
#   ['weird', 1],
#   ['pillow', 4],
#   ['ourselv', 1],
#   ['breathtaking', 1],
#   ['treasure', 1],
#   ['love', 43],
#   ['extra', 14],
#   ['prefer', 3],
#   ['stingi', 1],
#   ['upstair', 1],
#   ['marvelous', 1],
#   ['fantasticoceanview', 1],
#   ['prompt', 1],
#   ['market', 2],
#   ['hotels', 3],
#   ['flavors', 1],
#   ['memori', 1],
#   ['perk', 2],
#   ['hyatt', 1],
#   ['visit', 16],
#   ['live', 2],
#   ['loung', 2],
#   ['criteria', 1],
#   ['suppos', 3],
#   ['thru', 2],
#   ['checkout', 5],
#   ['today', 2],
#   ['snorkelling', 1],
#   ['club', 2],
#   ['peopl', 27],
#   ['clue', 1],
#   ['downtown', 1],
#   ['travelhawaii', 2],
#   ['dismal', 1],
#   ['effort', 2],
#   ['summertim', 1],
#   ['car', 23],
#   ['prepar', 4],
#   ['judg', 1],
#   ['ulu', 3],
#   ['reviews', 3],
#   ['wallet', 2],
#   ['can', 46],
#   ['cam', 1],
#   ['webstes', 1],
#   ['streak', 1],
#   ['nearest', 1],
#   ['fabul', 2],
#   ['interenet', 1],
#   ['awesome', 8],
#   ['agent', 1],
#   ['wakikik', 1],
#   ['heard', 6],
#   ['critic', 1],
#   ['yard', 1],
#   ['spa', 2],
#   ['surfers', 2],
#   ['occur', 1],
#   ['occup', 1],
#   ['multipl', 1],
#   ['soleil', 1],
#   ['get', 57],
#   ['notsogreat', 1],
#   ['write', 3],
#   ['alway', 19],
#   ['anyon', 10],
#   ['tile', 4],
#   ['nyc', 3],
#   ['nonstop', 1],
#   ['diamondhead', 4],
#   ['product', 2],
#   ['mat', 1],
#   ['may', 9],
#   ['southern', 1],
#   ['birthday', 4],
#   ['laundri', 2],
#   ['mad', 1],
#   ['armoir', 1],
#   ['date', 2],
#   ['filthy', 2],
#   ['man', 1],
#   ['againgood', 1],
#   ['practic', 1],
#   ['sq', 1],
#   ['favorit', 1],
#   ['inform', 3],
#   ['truck', 1],
#   ['lagoon', 1],
# ...
#   ['early', 1],
#   ['convieni', 1],
#   ['kept', 3],
#   ['center', 2],
#   ['choos', 3],
#   ['entri', 1],
#   ['happi', 1],
#   ['smoker', 1],
#   ['maker', 1],
#   ['thought', 2],
#   ['person', 3],
#   ['without', 1],
#   ['picki', 1],
#   ['elev', 5],
#   ['mother', 1],
#   ['everyth', 5],
#   ['spend', 1],
#   ['plaque', 2],
#   ['charged', 1],
#   ['taxi', 1],
#   ['summer', 1],
#   ['stores', 1],
#   ['just', 13],
#   ['less', 4],
#   ['money', 4],
#   ['desk', 8],
#   ['rest', 1],
#   ['foot', 1],
#   ['violent', 1],
#   ['rooms', 2],
#   ['touch', 1],
#   ['speed', 1],
#   ['continent', 3],
#   ['previous', 4],
#   ['rundown', 1],
#   ['bagel', 1],
#   ['now', 1],
#   ['expos', 1],
#   ['mix', 1],
#   ['mcdonald', 1],
#   ['copi', 1],
#   ['extra', 1],
#   ['littl', 6],
#   ['complain', 2],
#   ['reconsid', 1],
#   ['unsanitari', 1],
#   ['crack', 1],
#   ['els', 1],
#   ['save', 1],
#   ['gave', 2],
#   ['swim', 1],
#   ['complaint', 2],
#   ['march', 1],
#   ['around', 3],
#   ['stunk', 1],
#   ['mayb', 1],
#   ['read', 4],
#   ['linens', 1],
#   ['ladi', 1],
#   ['suppos', 1],
#   ['regard', 1],
#   ['dark', 1],
#   ['game', 1],
#   ['traffic', 1],
#   ['know', 2],
#   ['mom', 3],
#   ['vacuum', 2],
#   ['bit', 3],
#   ['apart', 1],
#   ['towel', 7],
#   ['like', 11],
#   ['onion', 1],
#   ['sofa', 1],
#   ['negat', 1],
#   ['resolv', 3],
#   ['collect', 1],
#   ['either', 1],
#   ['robbery', 1],
#   ['night', 13],
#   ['poolsid', 1],
#   ['juic', 1],
#   ['manag', 5],
#   ['italian', 1],
#   ['encount', 1],
#   ['right', 7],
#   ['old', 9],
#   ['towels', 2],
#   ['deal', 1],
#   ['people', 1],
#   ['spring', 1],
#   ['clientel', 1],
#   ['back', 8],
#   ['dead', 2],
#   ['hair', 4],
#   ['championship', 1],
#   ['palm', 2],
#   ['flush', 2],
#   ['home', 3],
#   ['transport', 1],
#   ['confusing', 1],
#   ['gross', 1],
#   ['scald', 1],
#   ['slice', 1],
#   ['pail', 1],
#   ['criter', 1],
#   ['breadcheeriosmini', 1],
#   ['avoid', 1],
#   ['normal', 1],
#   ['definit', 1],
#   ['ice', 2],
#   ['larg', 6],
#   ['retro', 1],
#   ['pleasur', 2],
#   ['condit', 1],
#   ['speak', 1],
#   ['refer', 1],
#   ['machin', 3],
#   ['core', 1],
#   ['harras', 1],
#   ['run', 2],
#   ['peel', 2],
#   ['quit', 1],
#   ['odor', 1],
#   ['burn', 1],
#   ['confer', 2],
#   ['whi', 2],
#   ['broken', 4],
#   ['usd', 2],
#   ['although', 3],
#   ['fulli', 1],
#   ['post', 4],
#   ['super', 2],
#   ['dumpy', 1],
#   ['ciragrett', 1],
#   ['central', 1],
#   ['diner', 1],
#   ['oh', 1],
#   ['smear', 2],
#   ['complimentari', 1],
#   ['refold', 1],
#   ['separt', 1],
#   ['unfortun', 2],
#   ['coakroach', 1],
#   ['dinner', 1],
#   ['swear', 1],
#   ['plus', 2],
#   ['stand', 2],
#   ['roam', 1],
#   ['disabl', 1],
#   ['block', 3],
#   ['desper', 1],
#   ['dials', 1],
#   ['enough', 1],
#   ['within', 1],
#   ['someth', 1],
#   ['two', 8],
#   ['stop', 1],
#   ['phase', 1],
#   ['guard', 2],
#   ['weather', 1],
#   ['opportun', 1],
#   ['next', 6],
#   ['rolls', 1],
#   ['microwav', 1],
#   ['often', 1],
#   ['crowd', 1],
#   ['area', 17],
#   ['opend', 1],
#   ['question', 1],
#   ['long', 4],
#   ['custom', 1],
#   ['avail', 2],
#   ['start', 1],
#   ['joseph', 1],
#   ['low', 3],
#   ['stars', 1],
#   ['tepid', 1],
#   ['hassl', 1],
#   ['call', 5],
#   ['enorm', 1],
#   ['appoint', 1],
#   ['buy', 1],
#   ['north', 1],
#   ['interest', 1],
#   ['offer', 1],
#   ['hr', 1],
#   ['bus', 1],
#   ['brand', 1],
#   ['three', 1],
#   ['hiccup', 1],
#   ['properly', 1],
#   ['hear', 1],
#   ['refriger', 2],
#   ['line', 1],
#   ['eat', 2],
#   ['pull', 1],
#   ['hire', 2],
#   ['made', 8],
#   ['dirti', 6],
#   ['consist', 2],
#   ['upheld', 1],
#   ['wish', 2],
#   ['flip', 1],
#   ['us', 4],
#   ['commut', 1],
#   ['adequ', 1],
#   ['dirty', 1],
#   ['highlight', 1],
#   ['embed', 2],
#   ['unprofession', 1],
#   ['toilet', 3],
#   ['ac', 2],
#   ['againi', 1],
#   ['constant', 1],
#   ['play', 1],
#   ['taste', 1],
#   ['certain', 3],
#   ['dure', 2],
#   ['scarey', 2],
#   ['deep', 1],
#   ['dog', 3],
#   ['novemb', 1],
#   ['inn', 10],
#   ['carpark', 1],
#   ['muffins', 1],
#   ['az', 1],
#   ['mold', 1],
#   ['trip', 5],
#   ['showerhead', 1],
#   ['probabl', 2],
#   ['beyond', 1],
#   ['poolhot', 1],
#   ['loud', 4],
#   ['floor', 12],
#   ['excel', 1],
#   ['plumb', 1],
#   ['book', 4],
#   ['futur', 1],
#   ['sick', 2],
#   ['smell', 10],
#   ['roll', 1],
#   ['mock', 1],
#   ['nice', 13],
#   ['poor', 5],
#   ['repeat', 2],
#   ['star', 1],
#   ['determin', 1],
#   ['phoenix', 7],
#   ['disgraceful', 1],
#   ['knew', 1],
#   ['felt', 6],
#   ['june', 1],
#   ['stay', 34],
#   ['funki', 1],
#   ['scale', 1],
#   ['award', 1],
#   ['weekend', 3],
#   ['pool', 24],
#   ['ago', 2],
#   ['outdat', 1],
#   ['leav', 3],
#   ['wifi', 2],
#   ['age', 1],
#   ['groom', 1],
#   ['stale', 1],
#   ['beds', 2],
#   ['pet', 4],
#   ['train', 1],
#   ...],
#  u'73768': [['code', 1],
#   ['scratch', 1],
#   ['dollar', 1],
#   ['yellow', 1],
#   ['sleep', 1],
#   ['ice', 1],
#   ['go', 7],
#   ['follow', 1],
#   ['chair', 1],
#   ['hate', 2],
#   ['carpet', 4],
#   ['middl', 3],
#   ['tv', 1],
#   ['thursday', 1],
#   ['th', 1],
#   ['leav', 4],
#   ['worth', 2],
#   ['deactiv', 1],
#   ['wavi', 1],
#   ['everi', 4],
#   ['prepaid', 1],
#   ['checkin', 1],
#   ['mous', 1],
#   ['scout', 1],
#   ['fan', 2],
#   ['trough', 1],
#   ['veri', 19],
#   ['exact', 1],
#   ['cool', 4],
#   ['tri', 4],
#   ['heaven', 1],
#   ['die', 1],
#   ['wednesday', 2],
#   ['micowav', 1],
#   ['adjust', 1],
#   ['quick', 1],
#   ['guy', 2],
#   ['round', 1],
#   ['prevent', 1],
#   ['rusti', 1],
#   ['fortun', 2],
#   ['tea', 1],
#   ['traveler', 1],
#   ['straighten', 1],
#   ['past', 1],
#   ['second', 4],
#   ['cost', 2],
#   ['roof', 1],
#   ['nightim', 1],
#   ['odd', 1],
#   ['even', 5],
#   ['appear', 2],
#   ['filler', 1],
#   ['dirt', 1],
#   ['abl', 2],
#   ['inconveniences', 1],
#   ['pluse', 1],
#   ['suspect', 1],
#   ['new', 1],
#   ['ground', 5],
#   ['ever', 1],
#   ['told', 1],
#   ['full', 1],
#   ['led', 1],
#   ['chose', 1],
#   ['leg', 1],
#   ['clerk', 1],
#   ['never', 7],
#   ['water', 4],
#   ['sink', 1],
#   ['meet', 1],
#   ['alone', 1],
#   ['along', 1],
#   ['sinc', 2],
#   ['valu', 1],
#   ['wait', 1],
#   ['box', 2],
#   ['great', 5],
#   ['broken', 1],
#   ['changed', 1],
#   ['vacat', 1],
#   ['extremem', 1],
#   ['amount', 1],
#   ['smoke', 3],
#   ['fumbl', 1],
#   ['extrem', 2],
#   ['chang', 2],
#   ['honor', 1],
#   ['carpets', 1],
#   ['love', 1],
#   ['hoteli', 1],
#   ['extra', 3],
#   ['brought', 3],
#   ['famili', 2],
#   ['select', 1],
#   ['woprri', 1],
#   ['use', 6],
#   ['fee', 1],
#   ['describ', 1],
#   ['working', 1],
#   ['visit', 1],
#   ['two', 5],
#   ['next', 3],
#   ['live', 2],
#   ['morn', 2],
#   ['recommend', 3],
#   ['black', 1],
#   ['australian', 1],
#   ['minor', 1],
#   ['fridg', 1],
#   ['sort', 1],
#   ['flat', 1],
#   ['expedia', 1],
#   ['door', 9],
#   ['relax', 1],
#   ['peopl', 6],
#   ['relat', 1],
#   ['impress', 1],
#   ['notic', 3],
#   ['surprisingly', 1],
#   ['enjo', 1],
#   ['glass', 3],
#   ['train', 2],
#   ['broke', 1],
#   ['ok', 5],
#   ['compani', 2],
#   ['hold', 1],
#   ['outdated', 1],
#   ['glad', 1],
#   ['none', 1],
#   ['word', 1],
#   ['room', 45],
#   ['hour', 2],
#   ['car', 2],
#   ['prepar', 1],
#   ['work', 13],
#   ['worn', 2],
#   ['friendly', 1],
#   ['wors', 1],
#   ['can', 5],
#   ['following', 1],
#   ['downhil', 1],
#   ['plug', 2],
#   ['complain', 1],
#   ['control', 1],
#   ['heard', 1],
#   ['caution', 1],
#   ['want', 4],
#   ['sense', 1],
#   ['freshen', 1],
#   ['dress', 1],
#   ['condemn', 1],
#   ['huge', 2],
#   ['secur', 1],
#   ['rather', 3],
#   ['travel', 1],
#   ['comfort', 3],
#   ['alway', 1],
#   ['hot', 3],
#   ['anyon', 1],
#   ['answer', 1],
#   ['instead', 1],
#   ['poker', 1],
#   ['okay', 2],
#   ['rude', 2],
#   ['sir', 1],
#   ['overall', 1],
#   ['chines', 1],
#   ['shap', 1],
#   ['befor', 4],
#   ['lay', 1],
#   ['attent', 1],
#   ['man', 1],
#   ['short', 1],
#   ['attempt', 1],
#   ['light', 4],
#   ['counter', 1],
#   ['scare', 1],
#   ['mislead', 1],
#   ['polic', 1],
#   ['switch', 3],
#   ['gloomy', 1],
#   ['south', 1],
#   ['enter', 1],
#   ['plagu', 1],
#   ['worst', 1],
#   ['order', 1],
#   ['patio', 2],
#   ['jack', 2],
#   ['help', 1],
#   ['theyr', 1],
#   ['deactivated', 1],
#   ['move', 3],
#   ['becaus', 5],
#   ['jacuzzi', 2],
#   ['oven', 1],
#   ['smelli', 1],
#   ['mcdonalds', 1],
#   ['hook', 1],
#   ['group', 1],
#   ['thank', 1],
#   ['fix', 1],
#   ['lamp', 1],
#   ['bedbug', 1],
#   ['awfula', 1],
#   ['maid', 3],
#   ['offic', 5],
#   ['spacious', 1],
#   ['main', 1],
#   ['recept', 1],
#   ['hairdryer', 1],
#   ['good', 4],
#   ['return', 2],
#   ['citrus', 1],
#   ['safe', 1],
#   ['handi', 1],
#   ['break', 1],
#   ['promis', 2],
#   ['front', 7],
#   ['detach', 1],
#   ['day', 22],
#   ['dingi', 4],
#   ['choic', 2],
#   ['anyth', 1],
#   ['drop', 1],
#   ['separ', 1],
#   ['slide', 4],
#   ['trap', 1],
#   ['found', 1],
#   ['went', 7],
#   ['complet', 1],
#   ['side', 2],
#   ['denni', 1],
#   ['square', 1],
#   ['mental', 1],
#   ['exhaust', 1],
#   ['replac', 1],
#   ['hard', 2],
#   ['realli', 5],
#   ['line', 1],
#   ['expect', 3],
#   ['year', 5],
#   ['girl', 3],
#   ['saturday', 1],
#   ['really', 1],
#   ['suppos', 1],
#   ['safeti', 1],
#   ['open', 4],
#   ['motel', 3],
#   ['research', 1],
#   ['internet', 2],
#   ['got', 5],
#   ['highway', 1],
#   ['assist', 1],
#   ['insid', 2],
#   ['ast', 1],
#   ['hang', 1],
#   ['nightmar', 1],
#   ['given', 2],
#   ['inroom', 1],
#   ['someon', 2],
#   ['pleasant', 1],
#   ['small', 4],
#   ['reason', 2],
#   ['believ', 1],
#   ['element', 1],
#   ['ask', 4],
#   ['card', 3],
#   ['care', 2],
#   ['partner', 1],
#   ['ate', 1],
#   ['days', 1],
#   ['keep', 1],
#   ['thing', 5],
#   ['american', 1],
#   ['place', 13],
#   ['outsid', 3],
#   ['loud', 2],
#   ['think', 4],
#   ['frequent', 3],
#   ['first', 6],
#   ['beauti', 1],
#   ['feel', 4],
#   ['onc', 1],
#   ['wast', 1],
#   ['housekeep', 1],
#   ['one', 16],
#   ['wash', 1],
#   ['alreadi', 1],
#   ['done', 1],
#   ['directly', 1],
#   ['owner', 1],
#   ['horribl', 1],
#   ['drove', 1],
#   ['facil', 2],
#   ['differ', 7],
#   ['ancient', 1],
#   ['sheet', 4],
#   ['guest', 1],
#   ['service', 2],
#   ['slept', 1],
#   ['stori', 1],
#   ['twenti', 1],
#   ['final', 2],
#   ['boil', 1],
#   ['low', 1],
#   ['groundin', 1],
#   ['way', 4],
#   ['hotel', 27],
#   ['park', 5],
#   ['took', 2],
#   ['part', 4],
#   ['review', 5],
#   ['kind', 1],
#   ['provid', 1],
#   ['bother', 2],
#   ['atmospher', 1],
#   ['tree', 1],
#   ['rate', 3],
#   ['bed', 5],
#   ['shower', 1],
#   ['street', 3],
#   ['friend', 2],
#   ['cleaner', 2],
#   ['comput', 4],
#   ['nicer', 3],
#   ['terribl', 2],
#   ['beefi', 1],
#   ['beforehand', 1],
#   ['ani', 1],
#   ['say', 3],
#   ['showers', 1],
#   ['close', 2],
#   ['need', 9],
#   ['seen', 1],
#   ['seem', 3],
#   ['turn', 4],
#   ['saw', 1],
#   ['remodel', 2],
#   ['arbi', 1],
#   ['lid', 1],
#   ['afraid', 2],
#   ['luxuri', 1],
#   ['also', 2],
#   ['skinnydip', 1],
#   ['maintain', 2],
#   ['build', 10],
#   ['thoma', 1],
#   ['noth', 1],
#   ['parti', 1],
#   ['begin', 1],
#   ['sure', 3],
#   ['unless', 2],
#   ['normal', 1],
#   ['minimart', 1],
#   ['price', 4],
#   ['knew', 2],
#   ['buget', 1],
#   ['whi', 2],
#   ['paid', 1],
#   ['crash', 1],
#   ['mouth', 1],
#   ['sheets', 2],
#   ['charg', 1],
#   ['interject', 1],
#   ['lose', 1],
#   ['drive', 1],
#   ['face', 2],
#   ['freeway', 3],
#   ['furnish', 1],
#   ['clean', 13],
#   ['usual', 2],
#   ['someth', 4],
#   ['came', 1],
#   ['show', 1],
#   ['queen', 1],
#   ['cheap', 2],
#   ['permiss', 1],
#   ['rough', 1],
#   ['fine', 4],
#   ['find', 2],
#   ['staff', 6],
#   ['access', 3],
#   ['onli', 5],
#   ['locat', 2],
#   ['nois', 1],
#   ['pretti', 2],
#   ['explain', 1],
#   ['restaur', 1],
#   ['busi', 2],
#   ['tape', 1],
#   ['hope', 1],
#   ['meant', 1],
#   ['get', 12],
#   ['beat', 1],
#   ['familiar', 1],
#   ['stop', 2],
#   ['ceil', 2],
#   ['mainten', 2],
#   ['wrinkl', 1],
#   ['clerks', 1],
#   ['uncomfort', 1],
#   ['bar', 1],
#   ['patch', 1],
#   ['bad', 6],
#   ['troop', 1],
#   ['contain', 1],
#   ['courteous', 1],
#   ['laquinta', 3],
#   ['manger', 1],
#   ['dump', 2],
#   ['respons', 1],
#   ['reserv', 2],
#   ['cold', 1],
#   ['best', 2],
#   ['wonder', 1],
#   ['said', 2],
#   ['moldi', 1],
#   ['inconveni', 1],
#   ['away', 1],
#   ['superb', 1],
#   ['figur', 2],
#   ['across', 4],
#   ['amen', 2],
#   ['screen', 1],
#   ['however', 2],
#   ['entir', 1],
#   ['key', 4],
#   ['crawli', 1],
#   ['tub', 1],
#   ['come', 2],
#   ['kitchen', 2],
#   ['hairi', 1],
#   ['sketchi', 1],
#   ['wiggl', 1],
#   ['last', 4],
#   ['joke', 1],
#   ['quiet', 1],
#   ['nearbi', 1],
#   ['etc', 2],
#   ['tour', 2],
#   ['asked', 1],
#   ['cozi', 1],
#   ['vent', 1],
#   ['tone', 1],
#   ['point', 2],
#   ['applianc', 1],
#   ['schedul', 1],
#   ['pot', 6],
#   ['arriv', 7],
#   ['walk', 6],
#   ['breakfasta', 1],
#   ['cancel', 1],
#   ['mattress', 1],
#   ['scari', 2],
#   ['assum', 1],
#   ['damag', 1],
#   ['late', 3],
#   ['bathroom', 3],
#   ['angel', 1],
#   ['coupl', 2],
#   ['resort', 1],
#   ['west', 1],
#   ['three', 3],
#   ['much', 5],
#   ['curtain', 1],
#   ['tini', 1],
#   ['pm', 2],
#   ['spit', 1],
#   ['search', 1],
#   ['anywher', 1],
#   ['demand', 1],
#   ['balconi', 1],
#   ['plants', 1],
#   ['look', 10],
#   ['servic', 5],
#   ['properti', 1],
#   ['budget', 1],
#   ['air', 4],
#   ['will', 3],
#   ['near', 2],
#   ['bathtub', 1],
#   ['almost', 1],
#   ['deliv', 2],
#   ['non', 1],
#   ['iv', 1],
#   ['unsatisfactori', 1],
#   ['exterior', 1],
#   ['bucks', 1],
#   ['breakfast', 5],
#   ['worry', 1],
#   ['makeov', 1],
#   ['confirmed', 1],
#   ['belli', 1],
#   ['receiv', 4],
#   ['pay', 1],
#   ['make', 5],
#   ['trip', 3],
#   ['food', 4],
#   ['difficult', 2],
#   ['week', 3],
#   ['hallway', 4],
#   ['overal', 1],
#   ['dennys', 1],
#   ['wherea', 1],
#   ['lobbi', 4],
#   ['coffe', 8],
#   ['running', 1],
#   ['fruit', 1],
#   ['student', 1],
#   ['wherev', 1],
#   ['recent', 1],
#   ['drain', 1],
#   ['kept', 5],
#   ['older', 2],
#   ['entri', 1],
#   ['spent', 3],
#   ['pillow', 3],
#   ['thought', 2],
#   ['person', 2],
#   ['without', 1],
#   ['expens', 1],
#   ['elev', 1],
#   ['choos', 1],
#   ['everyth', 1],
#   ['tast', 1],
#   ['spend', 1],
#   ['left', 3],
#   ['explan', 1],
#   ['neighborhood', 3],
#   ['distanc', 1],
#   ['just', 7],
#   ['nd', 2],
#   ['press', 1],
#   ['kill', 1],
#   ['rooms', 1],
#   ['yes', 1],
#   ['continent', 3],
#   ['death', 1],
#   ['easi', 3],
#   ['trudg', 1],
#   ['except', 1],
#   ['littl', 4],
#   ['hall', 4],
#   ['board', 1],
#   ['wet', 1],
#   ['els', 3],
#   ['divorc', 1],
#   ['gave', 2],
#   ['complaint', 1],
#   ['march', 3],
#   ['around', 5],
#   ['read', 1],
#   ['big', 3],
#   ['ladi', 2],
#   ['fridge', 1],
#   ['dark', 3],
#   ['quest', 1],
#   ['traffic', 2],
#   ['know', 1],
#   ['desk', 9],
#   ['yougster', 1],
#   ['world', 1],
#   ['bit', 5],
#   ['furniture', 1],
#   ['vental', 1],
#   ['knock', 1],
#   ['towel', 4],
#   ['like', 10],
#   ['manual', 1],
#   ['remind', 1],
#   ['fork', 1],
#   ['night', 25],
#   ['candl', 1],
#   ['soft', 1],
#   ['manag', 4],
#   ['encount', 1],
#   ['right', 2],
#   ['old', 6],
#   ['deal', 2],
#   ['nighttim', 1],
#   ['spring', 1],
#   ['back', 7],
#   ['hair', 1],
#   ['proper', 1],
#   ['gross', 1],
#   ['scald', 1],
#   ['mood', 1],
#   ['leak', 2],
#   ['avoid', 3],
#   ['though', 1],
#   ['definit', 4],
#   ['per', 1],
#   ['exit', 1],
#   ['condit', 3],
#   ['selfrespect', 1],
#   ['thepoor', 1],
#   ['booking', 1],
#   ['cockroach', 1],
#   ['run', 3],
#   ['quit', 1],
#   ['odor', 1],
#   ['burn', 1],
#   ['speak', 1],
#   ['discount', 1],
#   ['step', 1],
#   ['colleg', 1],
#   ['discov', 1],
#   ['although', 3],
#   ['lounger', 1],
#   ['noisy', 3],
#   ['unsaf', 2],
#   ['actual', 1],
#   ['oh', 1],
#   ['kitchenette', 1],
#   ['materi', 1],
#   ['location', 1],
#   ['surround', 1],
#   ['degre', 1],
#   ['plus', 1],
#   ['afternoon', 1],
#   ['block', 2],
#   ['repair', 2],
#   ['vegas', 1],
#   ['effici', 1],
#   ['within', 2],
#   ['surviv', 1],
#   ['weather', 1],
#   ['smelly', 1],
#   ['heated', 1],
#   ['storag', 1],
#   ['microwav', 2],
#   ['occupi', 1],
#   ['area', 13],
#   ['long', 2],
#   ['custom', 1],
#   ['avail', 1],
#   ['starv', 1],
#   ['includ', 2],
#   ['lot', 7],
#   ['call', 2],
#   ['lowest', 1],
#   ['ago', 1],
#   ['north', 1],
#   ['unfriend', 1],
#   ['enough', 1],
#   ['grungi', 1],
#   ['happen', 1],
#   ['cloth', 1],
#   ['heat', 1],
#   ['overflow', 1],
#   ['ear', 1],
#   ['continenti', 1],
#   ['reset', 1],
#   ['made', 5],
#   ['wise', 1],
#   ['consist', 1],
#   ['possibl', 1],
#   ['us', 4],
#   ['stories', 1],
#   ['dirty', 2],
#   ['doc', 1],
#   ['otherwis', 1],
#   ['problem', 6],
#   ['toilet', 2],
#   ['ac', 1],
#   ['play', 1],
#   ['certain', 1],
#   ['dure', 1],
#   ['dog', 2],
#   ['inn', 9],
#   ['daily', 1],
#   ['aw', 2],
#   ['definet', 1],
#   ['check', 5],
#   ['probabl', 2],
#   ['incorrect', 1],
#   ['floor', 5],
#   ['excel', 2],
#   ['book', 4],
#   ['communic', 1],
#   ['sick', 2],
#   ['better', 1],
#   ['smell', 7],
#   ['nice', 13],
#   ['poor', 3],
#   ['phoenix', 4],
#   ['freez', 1],
#   ['stay', 27],
#   ['consid', 3],
#   ['reservation', 1],
#   ['supris', 1],
#   ['pool', 15],
#   ['building', 2],
#   ['outdat', 1],
#   ['e', 1],
#   ['happening', 1],
#   ['phone', 1],
#   ['reliabl', 1],
#   ['wifi', 2],
#   ['cabbag', 1],
#   ['hungri', 1],
#   ['beds', 1],
#   ['fifti', 1],
#   ['fact', 1],
#   ['time', 5],
#   ['serious', 2]]}

# %%
# Export our hotWords to a JSON file and then check that it was successful.  
with open('hotwords.txt', 'w') as outfile:  
    json.dump(hotWords, outfile)
    
with open('hotwords.txt') as json_file:  
    data_check = json.load(json_file)
#data_check

# %%
# Creates a master list of all words to compare to.  
i = 0
hotelswords = []
masterwords = []
while i < len(hotWords):
    #hotelswords = hotWords.values()[i]
    masterwords += zip(*(hotWords.values()[i]))[0]
    i=i+1
    
# Compare each word to the number of times it appears in the list. 1 is the flag, since the 1 is itself.
uniquecollection = []
i = 0
hotelswords = []
finalwordstemp = {}
finalwords = {}
while i < len(hotWords):
    hotelswords = zip(*hotWords.values()[i])[0]
    counter = 0
    for h_words in hotelswords:
        if(masterwords.count(h_words) == 1):
            counter = counter + 1
    finalwordstemp = {hotWords.keys()[i]: counter}
    finalwords.update(finalwordstemp)
    i=i+1

# %%
# Displays the number of unique words by hotelID.  
finalwords
# Out:
# {u'100506': 101,
#  u'1217974': 5,
#  u'150849': 5080,
#  u'214680': 503,
#  u'240124': 127,
#  u'2515575': 225,
#  u'287670': 534,
#  u'550994': 488,
#  u'655424': 1,
#  u'677703': 3,
#  u'72572': 511,
#  u'72579': 222,
#  u'72586': 357,
#  u'72598': 86,
#  u'73393': 240,
#  u'73644': 113,
#  u'73706': 53,
#  u'73712': 48,
#  u'73718': 123,
#  u'73727': 124,
#  u'73739': 151,
#  u'73743': 85,
#  u'73751': 35,
#  u'73757': 62,
#  u'73760': 88,
#  u'73768': 43}

# %%
finalwords
# Out:
# {u'100506': 101,
#  u'1217974': 5,
#  u'150849': 5080,
#  u'214680': 503,
#  u'240124': 127,
#  u'2515575': 225,
#  u'287670': 534,
#  u'550994': 488,
#  u'655424': 1,
#  u'677703': 3,
#  u'72572': 511,
#  u'72579': 222,
#  u'72586': 357,
#  u'72598': 86,
#  u'73393': 240,
#  u'73644': 113,
#  u'73706': 53,
#  u'73712': 48,
#  u'73718': 123,
#  u'73727': 124,
#  u'73739': 151,
#  u'73743': 85,
#  u'73751': 35,
#  u'73757': 62,
#  u'73760': 88,
#  u'73768': 43}

# %%
dict((a,b) for a,b in finalwords.items() if b<100)
# Out:
# {u'1217974': 5,
#  u'655424': 1,
#  u'677703': 3,
#  u'72598': 86,
#  u'73706': 53,
#  u'73712': 48,
#  u'73743': 85,
#  u'73751': 35,
#  u'73757': 62,
#  u'73760': 88,
#  u'73768': 43}
